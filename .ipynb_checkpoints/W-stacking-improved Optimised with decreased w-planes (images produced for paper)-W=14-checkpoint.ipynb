# %% [markdown]
# ## Reference:
#
# Ye, H. (2019). Accurate image reconstruction in radio interferometry (Doctoral thesis). https://doi.org/10.17863/CAM.39448
#
# Haoyang Ye, Stephen F Gull, Sze M Tan, Bojan Nikolic, Optimal gridding and degridding in radio interferometry imaging, Monthly Notices of the Royal Astronomical Society, Volume 491, Issue 1, January 2020, Pages 1146–1159, https://doi.org/10.1093/mnras/stz2970
#
# Github: https://github.com/zoeye859/Imaging-Tutorial

# %%
# %matplotlib notebook
import numpy as np
from scipy.optimize import leastsq, brent
from scipy.linalg import solve_triangular
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from time import process_time
from numpy.linalg import inv
np.set_printoptions(precision=6)
from Imaging_core_new import *
from Gridding_core import *
import pickle
with open("min_misfit_gridding_14.pkl", "rb") as pp:
    opt_funcs = pickle.load(pp)

# %% [markdown]
# ### 1. Read in the data

# %%
#########  Read in visibilities ##########
data = np.genfromtxt('out_barray_6d.csv', delimiter = ',')
jj = complex(0,1)
u_original = data.T[0]
v_original = data.T[1]
w_original = -data.T[2]
V_original = data.T[3] + jj*data.T[4]
n_uv = len(u_original)
uv_max = max(np.sqrt(u_original**2+v_original**2))
V,u,v,w = Visibility_minusw(V_original,u_original,v_original,w_original)

#### Determine the pixel size ####
X_size = 900 # image size on x-axis
Y_size = 900 # image size on y-axis
X_min = -np.pi/60. #You can change X_min and X_max in order to change the pixel size.
X_max = np.pi/60.
X = np.linspace(X_min, X_max, num=X_size+1)[0:X_size]
Y_min = -np.pi/60. #You can change Y_min and Y_max in order to change the pixel size.
Y_max = np.pi/60.
Y = np.linspace(Y_min,Y_max,num=Y_size+1)[0:Y_size]
pixel_resol_x = 180. * 60. * 60. * (X_max - X_min) / np.pi / X_size
pixel_resol_y = 180. * 60. * 60. * (Y_max - Y_min) / np.pi / Y_size
print ("The pixel size on x-axis is ", pixel_resol_x, " arcsec")
# Out:
# The pixel size on x-axis is  23.999999999999996  arcsec

# %% [markdown]
# ### 2. Determine w plane number Nw_2R

# %%
W = 14
M, x0, h = opt_funcs[W].M, opt_funcs[W].x0, opt_funcs[W].h
n0, w_values, dw = calcWgrid_offset(W, X_max, Y_max, w, x0, symm=True)
# Out:
# We will have 29 w-planes

# %% [markdown]
# ### 3 3D Gridding + Imaging + Correcting
#
# To know more about gridding, you can refer to https://github.com/zoeye859/Imaging-Tutorial
# #### Calculating gridding values for w respectively

# %%
Nfft = 1800
im_size = 1800
ind = find_nearestw(w_values, w)
C_w = cal_grid_w(w, w_values, ind, dw, W, h, M)
# Out:
# Elapsed time during the w gridding value calculation in seconds: 13.153710999999998

# %% [markdown]
# #### Gridding on w-axis

# %%
V_wgrid, u_wgrid, v_wgrid, beam_wgrid = grid_w_offset(V, u, v, w, C_w, w_values, W, len(w_values), ind, n0)
# Out:
# Elapsed time during the w-gridding calculation in seconds: 6.906198

# %% [markdown]
# #### Imaging

# %%
I_size = int(im_size*2*x0)
I_image = np.zeros((I_size,I_size),dtype = np.complex_)
B_image = np.zeros((I_size,I_size),dtype = np.complex_)

t2_start = process_time() 
for w_ind in range(len(w_values)):
    print ('Gridding the ', w_ind, 'th level facet out of ', len(w_values),' w facets.\n')
    V_update = np.asarray(V_wgrid[w_ind])
    u_update = np.asarray(u_wgrid[w_ind])
    v_update = np.asarray(v_wgrid[w_ind])
    beam_update = np.asarray(beam_wgrid[w_ind])
    V_grid, B_grid = grid_uv(V_update, u_update, v_update, beam_update, W, im_size, X_max, X_min, Y_max, Y_min, h, M)
    print ('FFT the ', w_ind, 'th level facet out of ', len(w_values),' w facets.\n')
    I_image += FFTnPShift_offset(V_grid, w_values[w_ind], X, Y, im_size, x0, n0)
    B_image += FFTnPShift_offset(B_grid, w_values[w_ind], X, Y, im_size, x0, n0)
    B_grid = np.zeros((im_size,im_size),dtype = np.complex_) 
    V_grid = np.zeros((im_size,im_size),dtype = np.complex_)
    
t2_stop = process_time()   
print("Elapsed time during imaging in seconds:", t2_stop-t2_start)
# Out:
# Gridding the  0 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 1.4560460000000006
# Elapsed time during the u/v gridding value calculation in seconds: 1.4687689999999982
# FFT the  0 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  1 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 4.435910999999997
# Elapsed time during the u/v gridding value calculation in seconds: 4.4699349999999995
# FFT the  1 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  2 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 6.690173999999999
# Elapsed time during the u/v gridding value calculation in seconds: 6.708848000000003
# FFT the  2 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  3 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 8.202112999999997
# Elapsed time during the u/v gridding value calculation in seconds: 8.221068000000002
# FFT the  3 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  4 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 10.449318000000005
# Elapsed time during the u/v gridding value calculation in seconds: 10.41952999999998
# FFT the  4 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  5 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 11.405950999999959
# Elapsed time during the u/v gridding value calculation in seconds: 11.32826
# FFT the  5 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  6 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 11.428270999999995
# Elapsed time during the u/v gridding value calculation in seconds: 12.34662800000001
# FFT the  6 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  7 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 11.337934000000018
# Elapsed time during the u/v gridding value calculation in seconds: 12.333123
# FFT the  7 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  8 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 13.242321999999945
# Elapsed time during the u/v gridding value calculation in seconds: 13.141301999999996
# FFT the  8 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  9 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 12.005081000000018
# Elapsed time during the u/v gridding value calculation in seconds: 11.989451000000031
# FFT the  9 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  10 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 11.939615000000003
# Elapsed time during the u/v gridding value calculation in seconds: 11.947485000000029
# FFT the  10 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  11 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 12.923864999999978
# Elapsed time during the u/v gridding value calculation in seconds: 12.031594999999925
# FFT the  11 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  12 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 12.064972000000125
# Elapsed time during the u/v gridding value calculation in seconds: 12.05330099999992
# FFT the  12 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  13 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 12.252010000000155
# Elapsed time during the u/v gridding value calculation in seconds: 12.19417999999996
# FFT the  13 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  14 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 10.73127999999997
# Elapsed time during the u/v gridding value calculation in seconds: 10.993195000000014
# FFT the  14 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  15 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 7.598105999999916
# Elapsed time during the u/v gridding value calculation in seconds: 7.603327000000036
# FFT the  15 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  16 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 5.433525999999802
# Elapsed time during the u/v gridding value calculation in seconds: 5.459186000000045
# FFT the  16 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  17 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 3.8300709999998617
# Elapsed time during the u/v gridding value calculation in seconds: 3.808533000000125
# FFT the  17 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  18 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 2.7859280000000126
# Elapsed time during the u/v gridding value calculation in seconds: 2.70657499999993
# FFT the  18 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  19 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 1.8213569999998072
# Elapsed time during the u/v gridding value calculation in seconds: 1.79654000000005
# FFT the  19 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  20 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 1.1878210000002127
# Elapsed time during the u/v gridding value calculation in seconds: 1.192653000000064
# FFT the  20 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  21 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.8372110000000248
# Elapsed time during the u/v gridding value calculation in seconds: 0.8282730000000811
# FFT the  21 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  22 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.3969369999999799
# Elapsed time during the u/v gridding value calculation in seconds: 0.40549700000019584
# FFT the  22 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  23 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.20496299999990697
# Elapsed time during the u/v gridding value calculation in seconds: 0.21242100000017672
# FFT the  23 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  24 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.12354500000014923
# Elapsed time during the u/v gridding value calculation in seconds: 0.12413300000002891
# FFT the  24 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  25 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.052433999999948355
# Elapsed time during the u/v gridding value calculation in seconds: 0.05663300000014715
# FFT the  25 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  26 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.024705000000039945
# Elapsed time during the u/v gridding value calculation in seconds: 0.031661999999869295
# FFT the  26 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  27 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0114610000000539
# Elapsed time during the u/v gridding value calculation in seconds: 0.012717000000066037
# FFT the  27 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  28 th level facet out of  29  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.006495000000086293
# Elapsed time during the u/v gridding value calculation in seconds: 0.009340999999949418
# FFT the  28 th level facet out of  29  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Elapsed time during imaging in seconds: 1646.664327

# %% [markdown]
# #### Rescale and have a look

# %%
I_image_now = image_rescale(I_image,im_size, n_uv)
B_image_now = image_rescale(B_image,im_size, n_uv)
plt.figure()
plt.imshow(np.rot90(I_image_now.real,1), origin = 'lower')
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
B_image_now[450,450]
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.14807034757385723+1.3903509356037537e-16j)

# %% [markdown]
# #### Correcting functions h(x)h(y) on x and y axis

# %% [markdown]
# #### W= 7, x0 = 0.25

# %%
Nfft = 900
# Use these for calculating gridding correction on the FFT grid
M = 32

I_xycorrected = xy_correct(I_image_now, opt_funcs[W], im_size, x0=0.25)
B_xycorrected = xy_correct(B_image_now, opt_funcs[W], im_size, x0=0.25)

# %% [markdown]
# #### Correcting function on z axis

# %%
lut = setup_lookup_table(opt_funcs[14], Nfine=256, degree=7)
Cor_gridz = z_correct_cal_offset(lut, X_min, X_max, Y_min, Y_max, dw, h, im_size, W, M, x0, n0)
I_zcorrected = z_correct(I_xycorrected, Cor_gridz, im_size, x0=0.25)
B_zcorrected = z_correct(B_xycorrected, Cor_gridz, im_size, x0=0.25)
#np.savetxt('I_Figure6.csv', I_zcorrected.real, delimiter = ',')

# %% [markdown]
# ### 4 DFT and FFT dirty image difference

# %%
I_DFT = np.loadtxt('I_DFT_900_out6db.csv', delimiter = ',')

# %%
I_dif = I_DFT - I_zcorrected.real
plt.figure()
plt.imshow(np.rot90(I_dif,1), origin = 'lower')
plt.colorbar()
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
rms = RMS(I_dif, im_size, 1, x0=0.25)
print (rms)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 3.408867171038325e-15
