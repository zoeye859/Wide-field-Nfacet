# %% [markdown]
# ## Reference:
#
# Ye, H. (2019). Accurate image reconstruction in radio interferometry (Doctoral thesis). https://doi.org/10.17863/CAM.39448
#
# Haoyang Ye, Stephen F Gull, Sze M Tan, Bojan Nikolic, Optimal gridding and degridding in radio interferometry imaging, Monthly Notices of the Royal Astronomical Society, Volume 491, Issue 1, January 2020, Pages 1146–1159, https://doi.org/10.1093/mnras/stz2970
#
# Github: https://github.com/zoeye859/Imaging-Tutorial

# %%
# %matplotlib notebook
import numpy as np
from scipy.optimize import leastsq, brent
from scipy.linalg import solve_triangular
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from time import process_time
from numpy.linalg import inv
np.set_printoptions(precision=16)
from Imaging_core_new import *
from Gridding_core import *
import pickle
with open("min_misfit_gridding_7.pkl", "rb") as pp:
    opt_funcs = pickle.load(pp)

# %% [markdown]
# ### 1. Read in the data

# %%
#########  Read in visibilities ##########
data = np.genfromtxt('simul3d.csv', delimiter = ',')
jj = complex(0,1)
u_original = data.T[2][1:]
v_original = data.T[3][1:]
w_original = data.T[4][1:]
V_original = data.T[5][1:] + jj*data.T[6][1:]
n_uv = len(u_original)
uv_max = max(np.sqrt(u_original**2+v_original**2))
V,u,v,w = Visibility_minusw(V_original,u_original,v_original,w_original)

#### Determine the pixel size ####
X_size = 300 # image size on x-axis
Y_size = 300 # image size on y-axis
X_min = -1.15/2 #You can change X_min and X_max in order to change the pixel size.
X_max = 1.15/2
X = np.linspace(X_min, X_max, num=X_size+1)[0:X_size]
Y_min = -1.15/2 #You can change Y_min and Y_max in order to change the pixel size.
Y_max = 1.15/2
Y = np.linspace(Y_min,Y_max,num=Y_size+1)[0:Y_size]
pixel_resol_x = 180. * 60. * 60. * (X_max - X_min) / np.pi / X_size
pixel_resol_y = 180. * 60. * 60. * (Y_max - Y_min) / np.pi / Y_size
print ("The pixel size on x-axis is ", pixel_resol_x, " arcsec")
# Out:
# The pixel size on x-axis is  790.681757280536  arcsec

# %% [markdown]
# ### 2. determine the number of w planes
#
# Here is a short introduction to the original W-Stacking method (Offringa, 2014). Starting from
#
# $V(u,v,w) = \int\int \frac{\text{d}l \text{d}m }{\sqrt{1-l^2-m^2}}I(l,m)\exp\left[-i2\pi\left(ul+vm+w\left(\sqrt{1-l^2-m^2}-1\right)\right)\right]	$
#
# The right-hand side can be separated into one part without any $w$-term and the rest which contains the $w$-term. For each given non--zero $w_i$, we have
#
# $V(u,v,w_i) = \int \int \mathrm{d}l \mathrm{d}m \frac{I(l,m)}{\sqrt{1-l^2-m^2}} \exp{[-i2\pi(ul+vm)]}\exp{\Big\{-i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
#
# For each given non-zero $w_i$, this is essentially a two--dimensional Fourier transform. By inverting the transform, we have:
#
# $\frac{I(l,m)}{\sqrt{1-l^2-m^2}} = \int \int \mathrm{d}u \mathrm{d}v V(u,v,w_i)\exp{[i2\pi(ul+vm)]}	\exp{\Big\{i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\} $
#
# If we integrate both sides along the $w$-axis from the minimum $w_{\rm min}$ to the maximum $w_{\rm max}$ on the right-hand side, the result is
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \int_{w_{\rm min}}^{w_{\rm max}} \mathrm{d}w \exp{\Big\{\mathrm{i}2\pi\Big[w\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
# $\int \int \mathrm{d}u \mathrm{d}v V(u,v,w)\exp{[i2\pi(ul+vm)]}$
#
# In practice, the values of $w$ are discretised into $N_w$ uniform samples along the $w$-axis,  can be written as:
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \sum_{n = 0}^{N_w-1}\exp{\Big\{i2\pi\Big[w_n\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}\int \int \mathrm{d}u \mathrm{d}v V(u,v,w_n)\exp{[i2\pi(ul+vm)]} $
#
# Following (Offringa, 2014), the separation of two subsequent $w$ values $\delta w$ should satisfy the criterion:
#
# $|\delta w 2\pi(\sqrt{1-l^2-m^2}-1)| \ll 1$
#
# If $\delta w$ is larger than this, more $w$ samples are needed. Hence, $N_w$ is determined by:
#
# $N_w \geq 2\pi(w_{\rm max} - w_{\rm min})\max_{l,m}(1-\sqrt{1-l^2-m^2})$

# %% [markdown]
# ### 2.1 Redetermin the number of w planes
#
# <img src="normalised_coordinate.png">
#
# In the normalised coordinate system plotted above, the field of view is confined in the region of $[-0.5,0.5]$. $x_0$ and $y_0$ represents how much of the image will be cropped after the FFT process （Ye,2019 on optimal gridding and degridding）. Here we have $x_0 = y_0$. The angular size of the map required for the FFT in $l$ is $l_{\rm range}/(2x_0)$, and is $N_x$ pixels. If $u$ is specified in wavelengths, it is multiplied by $l_{\rm range}/(2x_0)$ to convert to pixels, so that we redetermin the number of $w$-planes as:
#
# $N_x \geq (u_{\rm max}-u_{\rm min})l_{\rm range}/x_0$
#
# We now consider the choice of the $w$ or $z$ grid. We set the phase centre $z=0$ at $n=0$ and $z=-x_0$ at $n_{\rm min}$. In our improved W-Stacking, we do not apply FFT in the $z$ direction, so there is no advantage in oversampling the beam considerably. Consequently,
#
# $N_z \geq (w_{\rm max}-w_{\rm min})n_{\rm min}/x_0$
#
# The number of $w$-planes using least-misfit gridding function can therefore be determined as:
#
# $N_{w'} \equiv N_z \geq\frac{\max_{l,m}(1-\sqrt{1-l^2-m^2})(w_{\rm max} - w_{\rm min})}{x_0} + W$
#
# The additional $w$-planes enable visibilities located close to the top or bottom $w$-planes to be gridded to grids on both sides.
#
# The number of $w$-planes, $N_{w}$, determined by the original W-Stacking method is more than 1.5 times greater than the first part of $N_{w'}$. Thus, for given data, the improved W-Stacking method may require fewer $w$--planes than the original W-Stacking method. $x_0 = 0.25, W\geq 7$ is recommended so as to achieve the single precision limit in the image misfit level.

# %% [markdown]
# ### 2. Determine w plane number Nw_2R

# %%
W = 6
M, x0, h = opt_funcs[W].M, opt_funcs[W].x0, opt_funcs[W].h
Nw_2R, w_values, dw = Wplanes(W, X_max, Y_max, w, x0)
# Out:
# We will have 75 w-planes

# %% [markdown]
# ### 3 3D Gridding + Imaging + Correcting
#
# To know more about gridding, you can refer to https://github.com/zoeye859/Imaging-Tutorial
# #### Calculating gridding values for w respectively

# %%
Nfft = 600
im_size = 600
ind = find_nearestw(w_values, w)
C_w = cal_grid_w(w, w_values, ind, dw, W, h, M)
# Out:
# Elapsed time during the w gridding value calculation in seconds: 0.9117820000000001

# %% [markdown]
# #### Gridding on w-axis

# %%
V_wgrid, u_wgrid, v_wgrid, beam_wgrid = grid_w(V, u, v, w, C_w, w_values, W, Nw_2R, ind)
# Out:
# Elapsed time during the w-gridding calculation in seconds: 0.15591999999999961

# %% [markdown]
# #### Imaging

# %%
I_size = int(im_size*2*x0)
I_image = np.zeros((I_size,I_size),dtype = np.complex_)
B_image = np.zeros((I_size,I_size),dtype = np.complex_)

t2_start = process_time() 
for w_ind in range(Nw_2R):
    print ('Gridding the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    V_update = np.asarray(V_wgrid[w_ind])
    u_update = np.asarray(u_wgrid[w_ind])
    v_update = np.asarray(v_wgrid[w_ind])
    beam_update = np.asarray(beam_wgrid[w_ind])
    V_grid, B_grid = grid_uv(V_update, u_update, v_update, beam_update, W, im_size, X_max, X_min, Y_max, Y_min, h, M)
    print ('FFT the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    I_image += FFTnPShift(V_grid, w_values[w_ind], X, Y, im_size, x0)
    B_image += FFTnPShift(B_grid, w_values[w_ind], X, Y, im_size, x0)
    B_grid = np.zeros((im_size,im_size),dtype = np.complex_) 
    V_grid = np.zeros((im_size,im_size),dtype = np.complex_)
    
t2_stop = process_time()   
print("Elapsed time during imaging in seconds:", t2_stop-t2_start)
# Out:
# Gridding the  0 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.047873000000000054
# Elapsed time during the u/v gridding value calculation in seconds: 0.03841300000000025
# Elapsed time during the u/v gridding value calculation in seconds: 0.034818000000000016
# Elapsed time during the u/v gridding value calculation in seconds: 0.03571499999999972
# FFT the  0 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  1 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08304000000000045
# Elapsed time during the u/v gridding value calculation in seconds: 0.07204100000000047
# Elapsed time during the u/v gridding value calculation in seconds: 0.06874599999999997
# Elapsed time during the u/v gridding value calculation in seconds: 0.07375100000000057
# FFT the  1 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  2 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.11798900000000057
# Elapsed time during the u/v gridding value calculation in seconds: 0.11622500000000002
# Elapsed time during the u/v gridding value calculation in seconds: 0.10885799999999968
# Elapsed time during the u/v gridding value calculation in seconds: 0.11740500000000065
# FFT the  2 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  3 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14372600000000002
# Elapsed time during the u/v gridding value calculation in seconds: 0.15443500000000032
# Elapsed time during the u/v gridding value calculation in seconds: 0.1538339999999998
# Elapsed time during the u/v gridding value calculation in seconds: 0.16015599999999974
# FFT the  3 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  4 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.18963099999999855
# Elapsed time during the u/v gridding value calculation in seconds: 0.1865780000000008
# Elapsed time during the u/v gridding value calculation in seconds: 0.1824539999999999
# Elapsed time during the u/v gridding value calculation in seconds: 0.19070700000000151
# FFT the  4 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  5 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.222213
# Elapsed time during the u/v gridding value calculation in seconds: 0.2259290000000007
# Elapsed time during the u/v gridding value calculation in seconds: 0.2066909999999993
# Elapsed time during the u/v gridding value calculation in seconds: 0.2276669999999985
# FFT the  5 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  6 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.22916399999999904
# Elapsed time during the u/v gridding value calculation in seconds: 0.20849399999999996
# Elapsed time during the u/v gridding value calculation in seconds: 0.21248999999999896
# Elapsed time during the u/v gridding value calculation in seconds: 0.2065090000000005
# FFT the  6 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  7 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.20533800000000113
# Elapsed time during the u/v gridding value calculation in seconds: 0.21253100000000025
# Elapsed time during the u/v gridding value calculation in seconds: 0.19306300000000043
# Elapsed time during the u/v gridding value calculation in seconds: 0.21332900000000166
# FFT the  7 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  8 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.19774599999999865
# Elapsed time during the u/v gridding value calculation in seconds: 0.2002890000000015
# Elapsed time during the u/v gridding value calculation in seconds: 0.18127899999999997
# Elapsed time during the u/v gridding value calculation in seconds: 0.20692400000000077
# FFT the  8 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  9 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.19695199999999957
# Elapsed time during the u/v gridding value calculation in seconds: 0.20091599999999943
# Elapsed time during the u/v gridding value calculation in seconds: 0.18560700000000097
# Elapsed time during the u/v gridding value calculation in seconds: 0.2052820000000004
# FFT the  9 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  10 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.18994299999999953
# Elapsed time during the u/v gridding value calculation in seconds: 0.19347899999999996
# Elapsed time during the u/v gridding value calculation in seconds: 0.17216500000000323
# Elapsed time during the u/v gridding value calculation in seconds: 0.1932799999999979
# FFT the  10 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  11 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.18835699999999989
# Elapsed time during the u/v gridding value calculation in seconds: 0.19730700000000212
# Elapsed time during the u/v gridding value calculation in seconds: 0.17995499999999964
# Elapsed time during the u/v gridding value calculation in seconds: 0.19722699999999804
# FFT the  11 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  12 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.19697299999999984
# Elapsed time during the u/v gridding value calculation in seconds: 0.19729300000000194
# Elapsed time during the u/v gridding value calculation in seconds: 0.17300600000000088
# Elapsed time during the u/v gridding value calculation in seconds: 0.19702200000000047
# FFT the  12 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  13 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1762750000000004
# Elapsed time during the u/v gridding value calculation in seconds: 0.18965100000000135
# Elapsed time during the u/v gridding value calculation in seconds: 0.17147100000000037
# Elapsed time during the u/v gridding value calculation in seconds: 0.1920579999999994
# FFT the  13 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  14 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1822979999999994
# Elapsed time during the u/v gridding value calculation in seconds: 0.1869000000000014
# Elapsed time during the u/v gridding value calculation in seconds: 0.17159399999999891
# Elapsed time during the u/v gridding value calculation in seconds: 0.19100099999999998
# FFT the  14 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  15 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.18189999999999884
# Elapsed time during the u/v gridding value calculation in seconds: 0.17614200000000224
# Elapsed time during the u/v gridding value calculation in seconds: 0.1610820000000004
# Elapsed time during the u/v gridding value calculation in seconds: 0.182580999999999
# FFT the  15 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  16 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.17660100000000156
# Elapsed time during the u/v gridding value calculation in seconds: 0.18281100000000094
# Elapsed time during the u/v gridding value calculation in seconds: 0.16199399999999997
# Elapsed time during the u/v gridding value calculation in seconds: 0.18313400000000257
# FFT the  16 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  17 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1689670000000021
# Elapsed time during the u/v gridding value calculation in seconds: 0.17640199999999595
# Elapsed time during the u/v gridding value calculation in seconds: 0.1523559999999975
# Elapsed time during the u/v gridding value calculation in seconds: 0.17722499999999997
# FFT the  17 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  18 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.16574800000000067
# Elapsed time during the u/v gridding value calculation in seconds: 0.17736899999999878
# Elapsed time during the u/v gridding value calculation in seconds: 0.15340799999999888
# Elapsed time during the u/v gridding value calculation in seconds: 0.1715639999999965
# FFT the  18 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  19 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15836699999999837
# Elapsed time during the u/v gridding value calculation in seconds: 0.17444499999999863
# Elapsed time during the u/v gridding value calculation in seconds: 0.14437300000000164
# Elapsed time during the u/v gridding value calculation in seconds: 0.16668100000000408
# FFT the  19 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  20 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15202400000000438
# Elapsed time during the u/v gridding value calculation in seconds: 0.15720400000000012
# Elapsed time during the u/v gridding value calculation in seconds: 0.13594499999999954
# Elapsed time during the u/v gridding value calculation in seconds: 0.1580149999999989
# FFT the  20 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  21 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14679900000000146
# Elapsed time during the u/v gridding value calculation in seconds: 0.15849500000000205
# Elapsed time during the u/v gridding value calculation in seconds: 0.13242699999999985
# Elapsed time during the u/v gridding value calculation in seconds: 0.15284499999999923
# FFT the  21 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  22 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1438360000000003
# Elapsed time during the u/v gridding value calculation in seconds: 0.1475149999999985
# Elapsed time during the u/v gridding value calculation in seconds: 0.12477799999999917
# Elapsed time during the u/v gridding value calculation in seconds: 0.15405899999999662
# FFT the  22 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  23 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.13770600000000144
# Elapsed time during the u/v gridding value calculation in seconds: 0.14529100000000028
# Elapsed time during the u/v gridding value calculation in seconds: 0.1363150000000033
# Elapsed time during the u/v gridding value calculation in seconds: 0.1380059999999972
# FFT the  23 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  24 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1337210000000013
# Elapsed time during the u/v gridding value calculation in seconds: 0.13714400000000637
# Elapsed time during the u/v gridding value calculation in seconds: 0.12962299999999516
# Elapsed time during the u/v gridding value calculation in seconds: 0.13384499999999377
# FFT the  24 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  25 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.13226099999999974
# Elapsed time during the u/v gridding value calculation in seconds: 0.12443199999999877
# Elapsed time during the u/v gridding value calculation in seconds: 0.11741599999999863
# Elapsed time during the u/v gridding value calculation in seconds: 0.13217199999999707
# FFT the  25 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  26 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1172949999999986
# Elapsed time during the u/v gridding value calculation in seconds: 0.11698599999999715
# Elapsed time during the u/v gridding value calculation in seconds: 0.10723399999999828
# Elapsed time during the u/v gridding value calculation in seconds: 0.12098799999999699
# FFT the  26 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  27 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.11055000000000348
# Elapsed time during the u/v gridding value calculation in seconds: 0.11010500000000434
# Elapsed time during the u/v gridding value calculation in seconds: 0.10725799999999452
# Elapsed time during the u/v gridding value calculation in seconds: 0.10705199999999593
# FFT the  27 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  28 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.10303900000000255
# Elapsed time during the u/v gridding value calculation in seconds: 0.10034100000000024
# Elapsed time during the u/v gridding value calculation in seconds: 0.10284599999999955
# Elapsed time during the u/v gridding value calculation in seconds: 0.10353900000000493
# FFT the  28 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  29 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.10663199999999762
# Elapsed time during the u/v gridding value calculation in seconds: 0.10638499999999596
# Elapsed time during the u/v gridding value calculation in seconds: 0.09712399999999377
# Elapsed time during the u/v gridding value calculation in seconds: 0.09351099999999946
# FFT the  29 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  30 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09852000000000061
# Elapsed time during the u/v gridding value calculation in seconds: 0.08672900000000539
# Elapsed time during the u/v gridding value calculation in seconds: 0.09510399999999919
# Elapsed time during the u/v gridding value calculation in seconds: 0.08795800000000042
# FFT the  30 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  31 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09313100000000674
# Elapsed time during the u/v gridding value calculation in seconds: 0.08806700000000234
# Elapsed time during the u/v gridding value calculation in seconds: 0.08850299999999578
# Elapsed time during the u/v gridding value calculation in seconds: 0.10147299999999859
# FFT the  31 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  32 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09168599999999572
# Elapsed time during the u/v gridding value calculation in seconds: 0.08088099999999798
# Elapsed time during the u/v gridding value calculation in seconds: 0.08682499999999749
# Elapsed time during the u/v gridding value calculation in seconds: 0.08529199999999548
# FFT the  32 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  33 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09087499999999693
# Elapsed time during the u/v gridding value calculation in seconds: 0.08508599999999689
# Elapsed time during the u/v gridding value calculation in seconds: 0.09086400000000339
# Elapsed time during the u/v gridding value calculation in seconds: 0.0848489999999984
# FFT the  33 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  34 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0833200000000005
# Elapsed time during the u/v gridding value calculation in seconds: 0.07769300000000356
# Elapsed time during the u/v gridding value calculation in seconds: 0.07387799999999345
# Elapsed time during the u/v gridding value calculation in seconds: 0.0778579999999991
# FFT the  34 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  35 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08691799999999716
# Elapsed time during the u/v gridding value calculation in seconds: 0.06975599999999815
# Elapsed time during the u/v gridding value calculation in seconds: 0.07499200000000172
# Elapsed time during the u/v gridding value calculation in seconds: 0.07785400000000209
# FFT the  35 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  36 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07427699999999504
# Elapsed time during the u/v gridding value calculation in seconds: 0.0702969999999965
# Elapsed time during the u/v gridding value calculation in seconds: 0.058709000000000344
# Elapsed time during the u/v gridding value calculation in seconds: 0.0732980000000012
# FFT the  36 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  37 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0706780000000009
# Elapsed time during the u/v gridding value calculation in seconds: 0.06414900000000046
# Elapsed time during the u/v gridding value calculation in seconds: 0.05469899999999939
# Elapsed time during the u/v gridding value calculation in seconds: 0.07079099999999983
# FFT the  37 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  38 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.06481799999998827
# Elapsed time during the u/v gridding value calculation in seconds: 0.052995000000009895
# Elapsed time during the u/v gridding value calculation in seconds: 0.053743999999994685
# Elapsed time during the u/v gridding value calculation in seconds: 0.06156800000000828
# FFT the  38 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  39 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.05586499999999717
# Elapsed time during the u/v gridding value calculation in seconds: 0.048005000000003406
# Elapsed time during the u/v gridding value calculation in seconds: 0.04306599999999605
# Elapsed time during the u/v gridding value calculation in seconds: 0.04681999999999675
# FFT the  39 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  40 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.052270000000007144
# Elapsed time during the u/v gridding value calculation in seconds: 0.04297100000000853
# Elapsed time during the u/v gridding value calculation in seconds: 0.040409999999994284
# Elapsed time during the u/v gridding value calculation in seconds: 0.042023000000000366
# FFT the  40 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  41 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.04431499999999744
# Elapsed time during the u/v gridding value calculation in seconds: 0.043275999999991654
# Elapsed time during the u/v gridding value calculation in seconds: 0.03510599999999897
# Elapsed time during the u/v gridding value calculation in seconds: 0.0385480000000058
# FFT the  41 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  42 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.04314100000000565
# Elapsed time during the u/v gridding value calculation in seconds: 0.03536000000001138
# Elapsed time during the u/v gridding value calculation in seconds: 0.03330800000000522
# Elapsed time during the u/v gridding value calculation in seconds: 0.036429999999995744
# FFT the  42 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  43 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03568599999999833
# Elapsed time during the u/v gridding value calculation in seconds: 0.03113500000000613
# Elapsed time during the u/v gridding value calculation in seconds: 0.027623000000005504
# Elapsed time during the u/v gridding value calculation in seconds: 0.03336099999999931
# FFT the  43 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  44 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03895099999999729
# Elapsed time during the u/v gridding value calculation in seconds: 0.0328049999999962
# Elapsed time during the u/v gridding value calculation in seconds: 0.027535999999997784
# Elapsed time during the u/v gridding value calculation in seconds: 0.031353000000009956
# FFT the  44 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  45 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.04021099999999933
# Elapsed time during the u/v gridding value calculation in seconds: 0.03038999999999703
# Elapsed time during the u/v gridding value calculation in seconds: 0.025664000000006126
# Elapsed time during the u/v gridding value calculation in seconds: 0.035307000000003086
# FFT the  45 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  46 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03944000000001324
# Elapsed time during the u/v gridding value calculation in seconds: 0.027682999999996127
# Elapsed time during the u/v gridding value calculation in seconds: 0.02547400000000266
# Elapsed time during the u/v gridding value calculation in seconds: 0.0309869999999961
# FFT the  46 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  47 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03425299999999254
# Elapsed time during the u/v gridding value calculation in seconds: 0.025195999999994
# Elapsed time during the u/v gridding value calculation in seconds: 0.022946000000004574
# Elapsed time during the u/v gridding value calculation in seconds: 0.036968000000001666
# FFT the  47 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  48 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.029083999999997445
# Elapsed time during the u/v gridding value calculation in seconds: 0.023980999999992036
# Elapsed time during the u/v gridding value calculation in seconds: 0.02121600000000967
# Elapsed time during the u/v gridding value calculation in seconds: 0.02708100000000968
# FFT the  48 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  49 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.02987299999999493
# Elapsed time during the u/v gridding value calculation in seconds: 0.02203500000000247
# Elapsed time during the u/v gridding value calculation in seconds: 0.019712999999995873
# Elapsed time during the u/v gridding value calculation in seconds: 0.023437000000001262
# FFT the  49 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  50 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.02624699999999791
# Elapsed time during the u/v gridding value calculation in seconds: 0.018906999999998675
# Elapsed time during the u/v gridding value calculation in seconds: 0.017036000000004492
# Elapsed time during the u/v gridding value calculation in seconds: 0.026375999999999067
# FFT the  50 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  51 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.02454299999999421
# Elapsed time during the u/v gridding value calculation in seconds: 0.01620900000000347
# Elapsed time during the u/v gridding value calculation in seconds: 0.014442000000002508
# Elapsed time during the u/v gridding value calculation in seconds: 0.021081000000009453
# FFT the  51 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  52 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0277409999999918
# Elapsed time during the u/v gridding value calculation in seconds: 0.016363999999995826
# Elapsed time during the u/v gridding value calculation in seconds: 0.014054000000001565
# Elapsed time during the u/v gridding value calculation in seconds: 0.017549999999999955
# FFT the  52 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  53 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.022728999999998223
# Elapsed time during the u/v gridding value calculation in seconds: 0.015390999999993937
# Elapsed time during the u/v gridding value calculation in seconds: 0.011435000000005857
# Elapsed time during the u/v gridding value calculation in seconds: 0.013790000000000191
# FFT the  53 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  54 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.021036999999992645
# Elapsed time during the u/v gridding value calculation in seconds: 0.012477999999987333
# Elapsed time during the u/v gridding value calculation in seconds: 0.009928000000002157
# Elapsed time during the u/v gridding value calculation in seconds: 0.012521000000006666
# FFT the  54 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  55 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.021623000000005277
# Elapsed time during the u/v gridding value calculation in seconds: 0.012429999999994834
# Elapsed time during the u/v gridding value calculation in seconds: 0.008684000000002357
# Elapsed time during the u/v gridding value calculation in seconds: 0.013267999999996505
# FFT the  55 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  56 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.015745999999992932
# Elapsed time during the u/v gridding value calculation in seconds: 0.01079799999999409
# Elapsed time during the u/v gridding value calculation in seconds: 0.0064429999999902066
# Elapsed time during the u/v gridding value calculation in seconds: 0.010968999999988682
# FFT the  56 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  57 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.011894999999995548
# Elapsed time during the u/v gridding value calculation in seconds: 0.006846999999993386
# Elapsed time during the u/v gridding value calculation in seconds: 0.005099000000001297
# Elapsed time during the u/v gridding value calculation in seconds: 0.0060520000000110485
# FFT the  57 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  58 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.011186000000009244
# Elapsed time during the u/v gridding value calculation in seconds: 0.00650100000000009
# Elapsed time during the u/v gridding value calculation in seconds: 0.003471999999987929
# Elapsed time during the u/v gridding value calculation in seconds: 0.005288999999990551
# FFT the  58 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  59 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.008827999999994063
# Elapsed time during the u/v gridding value calculation in seconds: 0.005073999999993362
# Elapsed time during the u/v gridding value calculation in seconds: 0.0027029999999967913
# Elapsed time during the u/v gridding value calculation in seconds: 0.004149999999995657
# FFT the  59 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  60 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.006028999999998064
# Elapsed time during the u/v gridding value calculation in seconds: 0.0038940000000025066
# Elapsed time during the u/v gridding value calculation in seconds: 0.001968000000005077
# Elapsed time during the u/v gridding value calculation in seconds: 0.0037679999999937763
# FFT the  60 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  61 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00747799999999188
# Elapsed time during the u/v gridding value calculation in seconds: 0.004880999999997471
# Elapsed time during the u/v gridding value calculation in seconds: 0.0021650000000050795
# Elapsed time during the u/v gridding value calculation in seconds: 0.00329599999999175
# FFT the  61 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  62 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00595799999999258
# Elapsed time during the u/v gridding value calculation in seconds: 0.005135999999993146
# Elapsed time during the u/v gridding value calculation in seconds: 0.003568999999998823
# Elapsed time during the u/v gridding value calculation in seconds: 0.00548500000000729
# FFT the  62 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  63 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.010383999999987736
# Elapsed time during the u/v gridding value calculation in seconds: 0.006273999999990565
# Elapsed time during the u/v gridding value calculation in seconds: 0.003330000000005384
# Elapsed time during the u/v gridding value calculation in seconds: 0.006164999999995757
# FFT the  63 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  64 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.008164000000007832
# Elapsed time during the u/v gridding value calculation in seconds: 0.007536999999999239
# Elapsed time during the u/v gridding value calculation in seconds: 0.0039770000000061145
# Elapsed time during the u/v gridding value calculation in seconds: 0.0072589999999905785
# FFT the  64 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  65 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.007081999999996924
# Elapsed time during the u/v gridding value calculation in seconds: 0.007481999999995992
# Elapsed time during the u/v gridding value calculation in seconds: 0.004483999999990829
# Elapsed time during the u/v gridding value calculation in seconds: 0.007010000000008176
# FFT the  65 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  66 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.007778000000001839
# Elapsed time during the u/v gridding value calculation in seconds: 0.0071120000000064465
# Elapsed time during the u/v gridding value calculation in seconds: 0.0036580000000014934
# Elapsed time during the u/v gridding value calculation in seconds: 0.006762999999992303
# FFT the  66 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  67 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.010004000000009228
# Elapsed time during the u/v gridding value calculation in seconds: 0.006252000000003477
# Elapsed time during the u/v gridding value calculation in seconds: 0.003158999999996581
# Elapsed time during the u/v gridding value calculation in seconds: 0.005507000000008588
# FFT the  67 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  68 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.005769000000000801
# Elapsed time during the u/v gridding value calculation in seconds: 0.00527200000000505
# Elapsed time during the u/v gridding value calculation in seconds: 0.0028459999999910224
# Elapsed time during the u/v gridding value calculation in seconds: 0.005213999999995167
# FFT the  68 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  69 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.004626000000001795
# Elapsed time during the u/v gridding value calculation in seconds: 0.0039579999999972415
# Elapsed time during the u/v gridding value calculation in seconds: 0.0020859999999913725
# Elapsed time during the u/v gridding value calculation in seconds: 0.004256999999995514
# FFT the  69 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  70 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0028480000000001837
# Elapsed time during the u/v gridding value calculation in seconds: 0.002392999999997869
# Elapsed time during the u/v gridding value calculation in seconds: 0.0013069999999970605
# Elapsed time during the u/v gridding value calculation in seconds: 0.0024409999999903675
# FFT the  70 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  71 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.002034000000008973
# Elapsed time during the u/v gridding value calculation in seconds: 0.0018500000000045702
# Elapsed time during the u/v gridding value calculation in seconds: 0.0010630000000020345
# Elapsed time during the u/v gridding value calculation in seconds: 0.0018180000000000973
# FFT the  71 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  72 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.001660000000001105
# Elapsed time during the u/v gridding value calculation in seconds: 0.0011379999999974189
# Elapsed time during the u/v gridding value calculation in seconds: 0.0012849999999957618
# Elapsed time during the u/v gridding value calculation in seconds: 0.0013469999999955462
# FFT the  72 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  73 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0014560000000045648
# Elapsed time during the u/v gridding value calculation in seconds: 0.000798000000003185
# Elapsed time during the u/v gridding value calculation in seconds: 0.0008219999999994343
# Elapsed time during the u/v gridding value calculation in seconds: 0.000770000000002824
# FFT the  73 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  74 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0011779999999959045
# Elapsed time during the u/v gridding value calculation in seconds: 0.0008279999999984966
# Elapsed time during the u/v gridding value calculation in seconds: 0.0008640000000070813
# Elapsed time during the u/v gridding value calculation in seconds: 0.0007219999999961146
# FFT the  74 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Elapsed time during imaging in seconds: 94.99313099999999

# %% [markdown]
# #### Rescale and have a look

# %%
I_image_now = image_rescale(I_image,im_size, n_uv)
B_image_now = image_rescale(B_image,im_size, n_uv)
plt.figure()
plt.imshow(np.rot90(I_image_now.real,1), origin = 'lower')
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
B_image_now[150,150]
# Out:
# <img src="data:image/png;base64,..." width="640">
# (1.0000000022353488+0j)

# %% [markdown]
# #### Correcting functions h(x)h(y) on x and y axis

# %% [markdown]
# #### W= 6, x0 = 0.25

# %%
Nfft = 600
# Use these for calculating gridding correction on the FFT grid
M = 32
I_xycorrected = xy_correct(I_image_now, opt_funcs[W], im_size, x0=0.25)
B_xycorrected = xy_correct(B_image_now, opt_funcs[W], im_size, x0=0.25)

# %% [markdown]
# #### Correcting function on z axis

# %%
Cor_gridz = z_correct_cal(X_min, X_max, Y_min, Y_max, dw, h, im_size, W, M, x0)
I_zcorrected = z_correct(I_xycorrected, Cor_gridz, im_size, x0=0.25)
B_zcorrected = z_correct(B_xycorrected, Cor_gridz, im_size, x0=0.25)

# %% [markdown]
# ### 4 DFT and FFT dirty image difference

# %%
I_DFT = np.loadtxt('I_DFT_simul300.csv', delimiter = ',')

# %%
I_dif = I_DFT - I_zcorrected.real
rms = RMS(I_dif, im_size, 0.5, x0=0.25)
plt.figure()
plt.imshow(np.rot90(I_dif,1), origin = 'lower')
plt.colorbar()
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print (rms)
# Out:
# 3.1153852973496086e-07
