# %% [markdown]
# ## Reference:
#
# Ye, H. (2019). Accurate image reconstruction in radio interferometry (Doctoral thesis). https://doi.org/10.17863/CAM.39448
#
# Haoyang Ye, Stephen F Gull, Sze M Tan, Bojan Nikolic, Optimal gridding and degridding in radio interferometry imaging, Monthly Notices of the Royal Astronomical Society, Volume 491, Issue 1, January 2020, Pages 1146–1159, https://doi.org/10.1093/mnras/stz2970
#
# Github: https://github.com/zoeye859/Imaging-Tutorial

# %%
# %matplotlib notebook
import numpy as np
from scipy.optimize import leastsq, brent
from scipy.linalg import solve_triangular
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from time import process_time
from numpy.linalg import inv
np.set_printoptions(precision=16)
from Imaging_core_new import *
from Gridding_core import *
import pickle
with open("min_misfit_gridding_7.pkl", "rb") as pp:
    opt_funcs = pickle.load(pp)

# %% [markdown]
# ### 1. Read in the data

# %%
#########  Read in visibilities ##########
data = np.genfromtxt('out_barray_6d.csv', delimiter = ',')
jj = complex(0,1)
u_original = data.T[0]
v_original = data.T[1]
w_original = -data.T[2]
V_original = data.T[3] + jj*data.T[4]
n_uv = len(u_original)
uv_max = max(np.sqrt(u_original**2+v_original**2))
V,u,v,w = Visibility_minusw(V_original,u_original,v_original,w_original)

#### Determine the pixel size ####
X_size = 900 # image size on x-axis
Y_size = 900 # image size on y-axis
X_min = -np.pi/60. #You can change X_min and X_max in order to change the pixel size.
X_max = np.pi/60.
X = np.linspace(X_min, X_max, num=X_size+1)[0:X_size]
Y_min = -np.pi/60. #You can change Y_min and Y_max in order to change the pixel size.
Y_max = np.pi/60.
Y = np.linspace(Y_min,Y_max,num=Y_size+1)[0:Y_size]
pixel_resol_x = 180. * 60. * 60. * (X_max - X_min) / np.pi / X_size
pixel_resol_y = 180. * 60. * 60. * (Y_max - Y_min) / np.pi / Y_size
print ("The pixel size on x-axis is ", pixel_resol_x, " arcsec")
# Out:
# The pixel size on x-axis is  23.999999999999996  arcsec

# %% [markdown]
# ### 2. determine the number of w planes
#
# Here is a short introduction to the original W-Stacking method (Offringa, 2014). Starting from
#
# $V(u,v,w) = \int\int \frac{\text{d}l \text{d}m }{\sqrt{1-l^2-m^2}}I(l,m)\exp\left[-i2\pi\left(ul+vm+w\left(\sqrt{1-l^2-m^2}-1\right)\right)\right]	$
#
# The right-hand side can be separated into one part without any $w$-term and the rest which contains the $w$-term. For each given non--zero $w_i$, we have
#
# $V(u,v,w_i) = \int \int \mathrm{d}l \mathrm{d}m \frac{I(l,m)}{\sqrt{1-l^2-m^2}} \exp{[-i2\pi(ul+vm)]}\exp{\Big\{-i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
#
# For each given non-zero $w_i$, this is essentially a two--dimensional Fourier transform. By inverting the transform, we have:
#
# $\frac{I(l,m)}{\sqrt{1-l^2-m^2}} = \int \int \mathrm{d}u \mathrm{d}v V(u,v,w_i)\exp{[i2\pi(ul+vm)]}	\exp{\Big\{i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\} $
#
# If we integrate both sides along the $w$-axis from the minimum $w_{\rm min}$ to the maximum $w_{\rm max}$ on the right-hand side, the result is
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \int_{w_{\rm min}}^{w_{\rm max}} \mathrm{d}w \exp{\Big\{\mathrm{i}2\pi\Big[w\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
# $\int \int \mathrm{d}u \mathrm{d}v V(u,v,w)\exp{[i2\pi(ul+vm)]}$
#
# In practice, the values of $w$ are discretised into $N_w$ uniform samples along the $w$-axis,  can be written as:
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \sum_{n = 0}^{N_w-1}\exp{\Big\{i2\pi\Big[w_n\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}\int \int \mathrm{d}u \mathrm{d}v V(u,v,w_n)\exp{[i2\pi(ul+vm)]} $
#
# Following (Offringa, 2014), the separation of two subsequent $w$ values $\delta w$ should satisfy the criterion:
#
# $|\delta w 2\pi(\sqrt{1-l^2-m^2}-1)| \ll 1$
#
# If $\delta w$ is larger than this, more $w$ samples are needed. Hence, $N_w$ is determined by:
#
# $N_w \geq 2\pi(w_{\rm max} - w_{\rm min})\max_{l,m}(1-\sqrt{1-l^2-m^2})$

# %% [markdown]
# ### 2.1 Redetermin the number of w planes
#
# <img src="normalised_coordinate.png">
#
# In the normalised coordinate system plotted above, the field of view is confined in the region of $[-0.5,0.5]$. $x_0$ and $y_0$ represents how much of the image will be cropped after the FFT process （Ye,2019 on optimal gridding and degridding）. Here we have $x_0 = y_0$. The angular size of the map required for the FFT in $l$ is $l_{\rm range}/(2x_0)$, and is $N_x$ pixels. If $u$ is specified in wavelengths, it is multiplied by $l_{\rm range}/(2x_0)$ to convert to pixels, so that we redetermin the number of $w$-planes as:
#
# $N_x \geq (u_{\rm max}-u_{\rm min})l_{\rm range}/x_0$
#
# We now consider the choice of the $w$ or $z$ grid. We set the phase centre $z=0$ at $n=0$ and $z=-x_0$ at $n_{\rm min}$. In our improved W-Stacking, we do not apply FFT in the $z$ direction, so there is no advantage in oversampling the beam considerably. Consequently,
#
# $N_z \geq (w_{\rm max}-w_{\rm min})n_{\rm min}/x_0$
#
# The number of $w$-planes using least-misfit gridding function can therefore be determined as:
#
# $N_{w'} \equiv N_z \geq\frac{\max_{l,m}(1-\sqrt{1-l^2-m^2})(w_{\rm max} - w_{\rm min})}{x_0} + W$
#
# The additional $w$-planes enable visibilities located close to the top or bottom $w$-planes to be gridded to grids on both sides.
#
# The number of $w$-planes, $N_{w}$, determined by the original W-Stacking method is more than 1.5 times greater than the first part of $N_{w'}$. Thus, for given data, the improved W-Stacking method may require fewer $w$--planes than the original W-Stacking method. $x_0 = 0.25, W\geq 7$ is recommended so as to achieve the single precision limit in the image misfit level.

# %% [markdown]
# ### 2. Determine w plane number Nw_2R

# %%
W = 7
M, x0, h = opt_funcs[W].M, opt_funcs[W].x0, opt_funcs[W].h
Nw_2R, w_values, dw = Wplanes(W, X_max, Y_max, w, x0)
# Out:
# We will have 37 w-planes

# %% [markdown]
# ### 3 3D Gridding + Imaging + Correcting
#
# To know more about gridding, you can refer to https://github.com/zoeye859/Imaging-Tutorial
# #### Calculating gridding values for w respectively

# %%
Nfft = 1800
im_size = 1800
ind = find_nearestw(w_values, w)
C_w = cal_grid_w(w, w_values, ind, dw, W, h, M)
# Out:
# Elapsed time during the w gridding value calculation in seconds: 8.94858099999999

# %% [markdown]
# #### Gridding on w-axis

# %%
V_wgrid, u_wgrid, v_wgrid, beam_wgrid = grid_w(V, u, v, w, C_w, w_values, W, Nw_2R, ind)
# Out:
# Elapsed time during the w-gridding calculation in seconds: 1.4677810000000022

# %% [markdown]
# #### Imaging

# %%
I_size = int(im_size*2*x0)
I_image = np.zeros((I_size,I_size),dtype = np.complex_)
B_image = np.zeros((I_size,I_size),dtype = np.complex_)

t2_start = process_time() 
for w_ind in range(Nw_2R):
    print ('Gridding the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    V_update = np.asarray(V_wgrid[w_ind])
    u_update = np.asarray(u_wgrid[w_ind])
    v_update = np.asarray(v_wgrid[w_ind])
    beam_update = np.asarray(beam_wgrid[w_ind])
    V_grid, B_grid = grid_uv(V_update, u_update, v_update, beam_update, W, im_size, X_max, X_min, Y_max, Y_min, h, M)
    print ('FFT the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    I_image += FFTnPShift(V_grid, w_values[w_ind], X, Y, im_size, x0)
    B_image += FFTnPShift(B_grid, w_values[w_ind], X, Y, im_size, x0)
    B_grid = np.zeros((im_size,im_size),dtype = np.complex_) 
    V_grid = np.zeros((im_size,im_size),dtype = np.complex_)
    
t2_stop = process_time()   
print("Elapsed time during imaging in seconds:", t2_stop-t2_start)
# Out:
# Gridding the  0 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.629035999999985
# Elapsed time during the u/v gridding value calculation in seconds: 0.616326000000015
# FFT the  0 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  1 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 2.0194510000000037
# Elapsed time during the u/v gridding value calculation in seconds: 1.8900800000000118
# FFT the  1 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  2 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 3.1184789999999794
# Elapsed time during the u/v gridding value calculation in seconds: 3.273112000000026
# FFT the  2 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  3 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 4.084071999999992
# Elapsed time during the u/v gridding value calculation in seconds: 4.278092000000015
# FFT the  3 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  4 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 5.112992000000077
# Elapsed time during the u/v gridding value calculation in seconds: 5.336658000000057
# FFT the  4 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  5 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 5.527975999999967
# Elapsed time during the u/v gridding value calculation in seconds: 5.822789999999941
# FFT the  5 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  6 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 6.668057999999974
# Elapsed time during the u/v gridding value calculation in seconds: 6.692256000000043
# FFT the  6 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  7 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 6.077385000000049
# Elapsed time during the u/v gridding value calculation in seconds: 6.288288999999963
# FFT the  7 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  8 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 5.219841000000088
# Elapsed time during the u/v gridding value calculation in seconds: 4.926199999999994
# FFT the  8 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  9 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 4.339126999999962
# Elapsed time during the u/v gridding value calculation in seconds: 4.258632000000034
# FFT the  9 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  10 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 3.770901999999978
# Elapsed time during the u/v gridding value calculation in seconds: 3.5560469999999214
# FFT the  10 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  11 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 2.9696190000000797
# Elapsed time during the u/v gridding value calculation in seconds: 3.028722000000016
# FFT the  11 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  12 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 2.887609999999995
# Elapsed time during the u/v gridding value calculation in seconds: 2.747835000000009
# FFT the  12 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  13 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 2.448742999999922
# Elapsed time during the u/v gridding value calculation in seconds: 2.570204999999987
# FFT the  13 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  14 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 2.129568000000063
# Elapsed time during the u/v gridding value calculation in seconds: 2.155510999999933
# FFT the  14 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  15 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 1.909501999999975
# Elapsed time during the u/v gridding value calculation in seconds: 1.9110510000000431
# FFT the  15 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  16 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 1.4479450000000043
# Elapsed time during the u/v gridding value calculation in seconds: 1.4171010000000024
# FFT the  16 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  17 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 1.4328309999999647
# Elapsed time during the u/v gridding value calculation in seconds: 1.3514590000000908
# FFT the  17 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  18 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 1.1188040000000683
# Elapsed time during the u/v gridding value calculation in seconds: 1.1114440000000059
# FFT the  18 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  19 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.8859300000000303
# Elapsed time during the u/v gridding value calculation in seconds: 0.8336400000000594
# FFT the  19 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  20 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.6660170000000107
# Elapsed time during the u/v gridding value calculation in seconds: 0.6666179999999713
# FFT the  20 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  21 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.52092899999991
# Elapsed time during the u/v gridding value calculation in seconds: 0.5642279999999573
# FFT the  21 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  22 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.42808500000001004
# Elapsed time during the u/v gridding value calculation in seconds: 0.42353099999991173
# FFT the  22 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  23 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.29728399999999056
# Elapsed time during the u/v gridding value calculation in seconds: 0.3134029999999939
# FFT the  23 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  24 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.2321350000000848
# Elapsed time during the u/v gridding value calculation in seconds: 0.2360200000000532
# FFT the  24 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  25 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.16332299999999123
# Elapsed time during the u/v gridding value calculation in seconds: 0.1790290000000141
# FFT the  25 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  26 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14156400000001668
# Elapsed time during the u/v gridding value calculation in seconds: 0.1512279999999464
# FFT the  26 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  27 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09597299999995812
# Elapsed time during the u/v gridding value calculation in seconds: 0.09939199999996617
# FFT the  27 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  28 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08133599999996477
# Elapsed time during the u/v gridding value calculation in seconds: 0.09510199999999713
# FFT the  28 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  29 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.05342900000005102
# Elapsed time during the u/v gridding value calculation in seconds: 0.0569510000000264
# FFT the  29 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  30 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03866500000003725
# Elapsed time during the u/v gridding value calculation in seconds: 0.046414000000027045
# FFT the  30 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  31 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.031319000000053165
# Elapsed time during the u/v gridding value calculation in seconds: 0.04204600000002756
# FFT the  31 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  32 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.02177500000004784
# Elapsed time during the u/v gridding value calculation in seconds: 0.02384000000006381
# FFT the  32 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  33 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.01385800000002746
# Elapsed time during the u/v gridding value calculation in seconds: 0.01741700000002311
# FFT the  33 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  34 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0046649999999317515
# Elapsed time during the u/v gridding value calculation in seconds: 0.008902999999918393
# FFT the  34 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  35 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00516400000003614
# Elapsed time during the u/v gridding value calculation in seconds: 0.009380000000078326
# FFT the  35 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  36 th level facet out of  37  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00317100000006576
# Elapsed time during the u/v gridding value calculation in seconds: 0.004737999999861131
# FFT the  36 th level facet out of  37  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Elapsed time during imaging in seconds: 553.632147

# %% [markdown]
# #### Rescale and have a look

# %%
I_image_now = image_rescale(I_image,im_size, n_uv)
B_image_now = image_rescale(B_image,im_size, n_uv)
plt.figure()
plt.imshow(np.rot90(I_image_now.real,1), origin = 'lower')
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
B_image_now[150,150]
# Out:
# <div id='1f699b1b-2112-4d29-92eb-59d736980280'></div>
# (-0.0020630484141426365-0.0023247533372835307j)

# %% [markdown]
# #### Correcting functions h(x)h(y) on x and y axis

# %% [markdown]
# #### W= 7, x0 = 0.25

# %%
Nfft = 600
# Use these for calculating gridding correction on the FFT grid
M = 32
I_xycorrected = xy_correct(I_image_now, opt_funcs[W], im_size, x0=0.25)
B_xycorrected = xy_correct(B_image_now, opt_funcs[W], im_size, x0=0.25)

# %% [markdown]
# #### Correcting function on z axis

# %%
Cor_gridz = z_correct_cal(X_min, X_max, Y_min, Y_max, dw, h, im_size, W, M, x0)
I_zcorrected = z_correct(I_xycorrected, Cor_gridz, im_size, x0=0.25)
B_zcorrected = z_correct(B_xycorrected, Cor_gridz, im_size, x0=0.25)

# %% [markdown]
# ### 4 DFT and FFT dirty image difference

# %%
I_DFT = np.loadtxt('I_DFT_900_out6db.csv', delimiter = ',')

# %%
I_dif = I_DFT - I_zcorrected.real
rms = RMS(I_dif, im_size, 0.5, x0=0.25)
plt.figure()
plt.imshow(np.rot90(I_dif,1), origin = 'lower')
plt.colorbar()
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print (rms)
# Out:
# 1.6018082130752818e-08
