# %% [markdown]
# ## Reference:
#
# Ye, H. (2019). Accurate image reconstruction in radio interferometry (Doctoral thesis). https://doi.org/10.17863/CAM.39448
#
# Haoyang Ye, Stephen F Gull, Sze M Tan, Bojan Nikolic, Optimal gridding and degridding in radio interferometry imaging, Monthly Notices of the Royal Astronomical Society, Volume 491, Issue 1, January 2020, Pages 1146–1159, https://doi.org/10.1093/mnras/stz2970
#
# Github: https://github.com/zoeye859/Imaging-Tutorial

# %%
# %matplotlib notebook
import numpy as np
from scipy.optimize import leastsq, brent
from scipy.linalg import solve_triangular
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from time import process_time
from numpy.linalg import inv
np.set_printoptions(precision=16)
from Imaging_core import *
from Gridding_core import *

# %% [markdown]
# ### 1. Read in the data

# %%
#########  Read in visibilities ##########
data = np.genfromtxt('simul3d.csv', delimiter = ',')
jj = complex(0,1)
u_original = data.T[2][1:]
v_original = data.T[3][1:]
w_original = data.T[4][1:]
V_original = data.T[5][1:] + jj*data.T[6][1:]
n_uv = len(u_original)
uv_max = max(np.sqrt(u_original**2+v_original**2))
V,u,v,w = Visibility_minusw(V_original,u_original,v_original,w_original)

#### Determine the pixel size ####
X_size = 300 # image size on x-axis
Y_size = 300 # image size on y-axis
X_min = -1.15/2 #You can change X_min and X_max in order to change the pixel size.
X_max = 1.15/2
X = np.linspace(X_min, X_max, num=X_size+1)[0:X_size]
Y_min = -1.15/2 #You can change Y_min and Y_max in order to change the pixel size.
Y_max = 1.15/2
Y = np.linspace(Y_min,Y_max,num=Y_size+1)[0:Y_size]
pixel_resol_x = 180. * 60. * 60. * (X_max - X_min) / np.pi / X_size
pixel_resol_y = 180. * 60. * 60. * (Y_max - Y_min) / np.pi / Y_size
print ("The pixel size on x-axis is ", pixel_resol_x, " arcsec")
# Out:
# The pixel size on x-axis is  790.681757280536  arcsec

# %% [markdown]
# ### 2. determine the number of w planes
#
# Here is a short introduction to the original W-Stacking method (Offringa, 2014). Starting from
#
# $V(u,v,w) = \int\int \frac{\text{d}l \text{d}m }{\sqrt{1-l^2-m^2}}I(l,m)\exp\left[-i2\pi\left(ul+vm+w\left(\sqrt{1-l^2-m^2}-1\right)\right)\right]	$
#
# The right-hand side can be separated into one part without any $w$-term and the rest which contains the $w$-term. For each given non--zero $w_i$, we have
#
# $V(u,v,w_i) = \int \int \mathrm{d}l \mathrm{d}m \frac{I(l,m)}{\sqrt{1-l^2-m^2}} \exp{[-i2\pi(ul+vm)]}\exp{\Big\{-i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
#
# For each given non-zero $w_i$, this is essentially a two--dimensional Fourier transform. By inverting the transform, we have:
#
# $\frac{I(l,m)}{\sqrt{1-l^2-m^2}} = \int \int \mathrm{d}u \mathrm{d}v V(u,v,w_i)\exp{[i2\pi(ul+vm)]}	\exp{\Big\{i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\} $
#
# If we integrate both sides along the $w$-axis from the minimum $w_{\rm min}$ to the maximum $w_{\rm max}$ on the right-hand side, the result is
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \int_{w_{\rm min}}^{w_{\rm max}} \mathrm{d}w \exp{\Big\{\mathrm{i}2\pi\Big[w\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
# $\int \int \mathrm{d}u \mathrm{d}v V(u,v,w)\exp{[i2\pi(ul+vm)]}$
#
# In practice, the values of $w$ are discretised into $N_w$ uniform samples along the $w$-axis,  can be written as:
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \sum_{n = 0}^{N_w-1}\exp{\Big\{i2\pi\Big[w_n\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}\int \int \mathrm{d}u \mathrm{d}v V(u,v,w_n)\exp{[i2\pi(ul+vm)]} $
#
# Following (Offringa, 2014), the separation of two subsequent $w$ values $\delta w$ should satisfy the criterion:
#
# $|\delta w 2\pi(\sqrt{1-l^2-m^2}-1)| \ll 1$
#
# If $\delta w$ is larger than this, more $w$ samples are needed. Hence, $N_w$ is determined by:
#
# $N_w \geq 2\pi(w_{\rm max} - w_{\rm min})\max_{l,m}(1-\sqrt{1-l^2-m^2})$

# %% [markdown]
# ### 2.1 Redetermin the number of w planes
#
# <img src="normalised_coordinate.png">
#
# In the normalised coordinate system plotted above, the field of view is confined in the region of $[-0.5,0.5]$. $x_0$ and $y_0$ represents how much of the image will be cropped after the FFT process （Ye,2019 on optimal gridding and degridding）. Here we have $x_0 = y_0$. The angular size of the map required for the FFT in $l$ is $l_{\rm range}/(2x_0)$, and is $N_x$ pixels. If $u$ is specified in wavelengths, it is multiplied by $l_{\rm range}/(2x_0)$ to convert to pixels, so that we redetermin the number of $w$-planes as:
#
# $N_x \geq (u_{\rm max}-u_{\rm min})l_{\rm range}/x_0$
#
# We now consider the choice of the $w$ or $z$ grid. We set the phase centre $z=0$ at $n=0$ and $z=-x_0$ at $n_{\rm min}$. In our improved W-Stacking, we do not apply FFT in the $z$ direction, so there is no advantage in oversampling the beam considerably. Consequently,
#
# $N_z \geq (w_{\rm max}-w_{\rm min})n_{\rm min}/x_0$
#
# The number of $w$-planes using least-misfit gridding function can therefore be determined as:
#
# $N_{w'} \equiv N_z \geq\frac{\max_{l,m}(1-\sqrt{1-l^2-m^2})(w_{\rm max} - w_{\rm min})}{x_0} + W$
#
# The additional $w$-planes enable visibilities located close to the top or bottom $w$-planes to be gridded to grids on both sides.
#
# The number of $w$-planes, $N_{w}$, determined by the original W-Stacking method is more than 1.5 times greater than the first part of $N_{w'}$. Thus, for given data, the improved W-Stacking method may require fewer $w$--planes than the original W-Stacking method. $x_0 = 0.25, W\geq 7$ is recommended so as to achieve the single precision limit in the image misfit level.

# %% [markdown]
# ### 2. Determine w plane number Nw_2R

# %%
W = 7
x0=0.25
Nw_2R, w_values, dw = Wplanes(W, X_max, Y_max, w, x0)
# Out:
# We will have 77 w-planes

# %% [markdown]
# #### Useful functions

# %%
### The calculated $h$ with $W = 6$ and $x_0=0.25$
opt7 = dict(W = 7, x0=0.25, h=np.array([
    1.0002272174008189,  1.0009091984458935,  1.0020469305033655,
    1.0036420619959552,  1.0056969066253769,  1.0082144493090053,
    1.0111983538519382,  1.0146529723826294,  1.0185833565892379,
    1.0229952707996748,  1.0278952069545397,  1.0332904015325726,
    1.0391888544929151,  1.045599350308597 ,  1.0525314811729209,
    1.0599956724713899,  1.0680032106181454,  1.0765662733693826,
    1.0856979627339742,  1.095412340614788 ,  1.1057244673249302,
    1.1166504431365301,  1.128207453033933 ,  1.1404138148559322,
    1.1532890310303459,  1.1668538441179874,  1.181130296403853 ,
    1.1961417937911953,  1.21191317427578  ,  1.2284707813008009,
    1.2458425423170127,  1.2640580528978707,  1.2831486667922027,
    1.3031475923210725,  1.3240899955670016,  1.3460131108345728,
    1.3689563589010425,  1.3929614736241018,  1.4180726375110748,
    1.4443366269145577,  1.4718029675661692,  1.5005241012250841,
    1.5305555642809532,  1.5619561792220744,  1.5947882599578642,
    1.6291178320673128,  1.6650148691391953,  1.7025535464695425,
    1.7418125134896449,  1.7828751864235401,  1.8258300627967712,
    1.8707710595713916,  1.9177978768316994,  1.9670163891222483,
    2.0185390667277656,  2.0724854293905373,  2.1289825351920761,
    2.1881655075695865,  2.2501781037235182,  2.3151733279606521,
    2.3833140938634734,  2.4547739395339461,  2.5297378005672715,
    2.6084028458568289]))

# %% [markdown]
# ### 3 3D Gridding + Imaging + Correcting
#
# To know more about gridding, you can refer to https://github.com/zoeye859/Imaging-Tutorial
# #### Calculating gridding values for w respectively

# %%
Nfft = 600
im_size = 600
W, x0, h = opt7["W"], opt7["x0"], opt7["h"] 
M = 32
ind = find_nearestw(w_values, w)
C_w = cal_grid_w(w, w_values, ind, dw, W, h)
# Out:
# /Users/yehaoyang/Documents/Wide-field-Nfacet/Gridding_core.py:48: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   C[:,m] = np.linalg.lstsq(B, rhs)[0]
# Elapsed time during the w gridding value calculation in seconds: 0.6724969999999999

# %% [markdown]
# #### Gridding on w-axis

# %%
bEAM = np.ones(n_uv)
V_wgrid = np.zeros((Nw_2R,1),dtype = np.complex_).tolist()
beam_wgrid = np.zeros((Nw_2R,1),dtype = np.complex_).tolist()
u_wgrid = np.zeros((Nw_2R,1)).tolist()
v_wgrid = np.zeros((Nw_2R,1)).tolist()
R = W//2
t2_start = process_time() 

for k in range(n_uv):
    C_wk = C_w[k]
    w_plane = ind[k]
    for n in range(-R+1,R+1):
        V_wgrid[w_plane+n] += [C_wk[n+R-1,0] * V[k]]
        u_wgrid[w_plane+n] += [u[k]]
        v_wgrid[w_plane+n] += [v[k]]
        beam_wgrid[w_plane+n] += [C_wk[n+R-1,0] * bEAM[k]]

t2_stop = process_time()   
print("Elapsed time during the w-gridding calculation in seconds:", t2_stop-t2_start)
# Out:
# Elapsed time during the w-gridding calculation in seconds: 0.15771999999999986

# %%
for i in range(Nw_2R):
    del(V_wgrid[i][0])
    del(u_wgrid[i][0])
    del(v_wgrid[i][0])
    del(beam_wgrid[i][0])

# %% [markdown]
# #### Imaging

# %%
I_size = int(im_size*2*x0)
V_grid = np.zeros((im_size,im_size),dtype = np.complex_)
B_grid = np.zeros((im_size,im_size),dtype = np.complex_) 
I_image = np.zeros((I_size,I_size),dtype = np.complex_)
B_image = np.zeros((I_size,I_size),dtype = np.complex_)


t2_start = process_time() 
for w_ind in range(Nw_2R):
    print ('Gridding the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    V_update = np.asarray(V_wgrid[w_ind])
    u_update = np.asarray(u_wgrid[w_ind])
    v_update = np.asarray(v_wgrid[w_ind])
    beam_update = np.asarray(beam_wgrid[w_ind])
    C_u, u_grid = cal_grid_uv(u_update, W, im_size, X_max, X_min, h, x0=0.25)
    C_v, v_grid = cal_grid_uv(v_update, W, im_size, Y_max, Y_min, h, x0=0.25)
    for k in range(0,len(V_wgrid[w_ind])):
        C_uk = C_u[k]
        C_vk = C_v[k]
        u_index = np.int(np.floor(u_grid[k]))
        v_index = np.int(np.floor(v_grid[k]))
        for m in range(-R+1,R+1):
            for n in range(-R+1,R+1):
                V_grid[u_index+m,v_index+n] += C_uk[m+R-1] * C_vk[n+R-1] * V_update[k]
                B_grid[u_index+m,v_index+n] += C_uk[m+R-1] * C_vk[n+R-1] * beam_update[k]
    print ('FFT the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    I_image += FFTnPShift(V_grid, w_values[w_ind], X, Y, im_size, x0)
    B_image += FFTnPShift(B_grid, w_values[w_ind], X, Y, im_size, x0)
    B_grid = np.zeros((im_size,im_size),dtype = np.complex_) 
    V_grid = np.zeros((im_size,im_size),dtype = np.complex_)
    
t2_stop = process_time()   
print("Elapsed time during the uv-gridding calculation in seconds:", t2_stop-t2_start)
# Out:
# Gridding the  0 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03432000000000013
# Elapsed time during the u/v gridding value calculation in seconds: 0.03030199999999983
# FFT the  0 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  1 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0671810000000006
# Elapsed time during the u/v gridding value calculation in seconds: 0.0548889999999993
# FFT the  1 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  2 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08852999999999955
# Elapsed time during the u/v gridding value calculation in seconds: 0.08278699999999972
# FFT the  2 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  3 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.11032500000000045
# Elapsed time during the u/v gridding value calculation in seconds: 0.13292400000000004
# FFT the  3 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  4 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14222599999999996
# Elapsed time during the u/v gridding value calculation in seconds: 0.14850799999999964
# FFT the  4 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  5 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15602400000000038
# Elapsed time during the u/v gridding value calculation in seconds: 0.166739999999999
# FFT the  5 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  6 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15697000000000116
# Elapsed time during the u/v gridding value calculation in seconds: 0.16270699999999927
# FFT the  6 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  7 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15282400000000074
# Elapsed time during the u/v gridding value calculation in seconds: 0.16305299999999967
# FFT the  7 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  8 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1611969999999996
# Elapsed time during the u/v gridding value calculation in seconds: 0.16591799999999957
# FFT the  8 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  9 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15291299999999985
# Elapsed time during the u/v gridding value calculation in seconds: 0.16739399999999982
# FFT the  9 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  10 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15324899999999886
# Elapsed time during the u/v gridding value calculation in seconds: 0.16577900000000056
# FFT the  10 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  11 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14436099999999996
# Elapsed time during the u/v gridding value calculation in seconds: 0.15932000000000102
# FFT the  11 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  12 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14937400000000167
# Elapsed time during the u/v gridding value calculation in seconds: 0.15409199999999856
# FFT the  12 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  13 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15182300000000026
# Elapsed time during the u/v gridding value calculation in seconds: 0.14759300000000053
# FFT the  13 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  14 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14337500000000247
# Elapsed time during the u/v gridding value calculation in seconds: 0.15203400000000045
# FFT the  14 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  15 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1326640000000019
# Elapsed time during the u/v gridding value calculation in seconds: 0.1464699999999972
# FFT the  15 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  16 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1371729999999971
# Elapsed time during the u/v gridding value calculation in seconds: 0.14766799999999947
# FFT the  16 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  17 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.13042700000000096
# Elapsed time during the u/v gridding value calculation in seconds: 0.13242400000000032
# FFT the  17 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  18 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1372499999999981
# Elapsed time during the u/v gridding value calculation in seconds: 0.1467160000000014
# FFT the  18 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  19 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.12940299999999993
# Elapsed time during the u/v gridding value calculation in seconds: 0.13153099999999895
# FFT the  19 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  20 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.12785300000000177
# Elapsed time during the u/v gridding value calculation in seconds: 0.11909600000000253
# FFT the  20 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  21 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.12127799999999667
# Elapsed time during the u/v gridding value calculation in seconds: 0.12078900000000203
# FFT the  21 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  22 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.11082300000000345
# Elapsed time during the u/v gridding value calculation in seconds: 0.11890199999999851
# FFT the  22 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  23 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.10627900000000068
# Elapsed time during the u/v gridding value calculation in seconds: 0.09999900000000395
# FFT the  23 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  24 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.10255099999999828
# Elapsed time during the u/v gridding value calculation in seconds: 0.09554100000000432
# FFT the  24 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  25 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09446499999999958
# Elapsed time during the u/v gridding value calculation in seconds: 0.0902499999999975
# FFT the  25 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  26 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0998999999999981
# Elapsed time during the u/v gridding value calculation in seconds: 0.0950729999999993
# FFT the  26 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  27 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07818900000000184
# Elapsed time during the u/v gridding value calculation in seconds: 0.07842499999999575
# FFT the  27 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  28 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0795180000000002
# Elapsed time during the u/v gridding value calculation in seconds: 0.07350600000000185
# FFT the  28 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  29 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08156500000000477
# Elapsed time during the u/v gridding value calculation in seconds: 0.0742000000000047
# FFT the  29 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  30 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08252999999999844
# Elapsed time during the u/v gridding value calculation in seconds: 0.06776700000000346
# FFT the  30 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  31 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0782610000000048
# Elapsed time during the u/v gridding value calculation in seconds: 0.0728069999999974
# FFT the  31 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  32 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07800399999999996
# Elapsed time during the u/v gridding value calculation in seconds: 0.06701600000000241
# FFT the  32 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  33 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07658199999999482
# Elapsed time during the u/v gridding value calculation in seconds: 0.06653699999999674
# FFT the  33 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  34 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.06417199999999923
# Elapsed time during the u/v gridding value calculation in seconds: 0.061079999999996915
# FFT the  34 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  35 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.06933699999999732
# Elapsed time during the u/v gridding value calculation in seconds: 0.05825899999999962
# FFT the  35 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  36 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0658639999999977
# Elapsed time during the u/v gridding value calculation in seconds: 0.049281000000000574
# FFT the  36 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  37 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.060687999999998965
# Elapsed time during the u/v gridding value calculation in seconds: 0.04883999999999844
# FFT the  37 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  38 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.05247099999999705
# Elapsed time during the u/v gridding value calculation in seconds: 0.04274199999999695
# FFT the  38 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  39 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.049205999999998085
# Elapsed time during the u/v gridding value calculation in seconds: 0.03442799999999835
# FFT the  39 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  40 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.046202000000000965
# Elapsed time during the u/v gridding value calculation in seconds: 0.030606000000005906
# FFT the  40 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  41 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03846500000000219
# Elapsed time during the u/v gridding value calculation in seconds: 0.027565000000002726
# FFT the  41 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  42 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.035329999999994754
# Elapsed time during the u/v gridding value calculation in seconds: 0.02780199999999411
# FFT the  42 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  43 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03771300000000366
# Elapsed time during the u/v gridding value calculation in seconds: 0.024426999999995758
# FFT the  43 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  44 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0322749999999985
# Elapsed time during the u/v gridding value calculation in seconds: 0.023161000000001764
# FFT the  44 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  45 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03605699999999956
# Elapsed time during the u/v gridding value calculation in seconds: 0.023021999999997433
# FFT the  45 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  46 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03235600000000005
# Elapsed time during the u/v gridding value calculation in seconds: 0.0225550000000041
# FFT the  46 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  47 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03501399999999677
# Elapsed time during the u/v gridding value calculation in seconds: 0.02075500000000119
# FFT the  47 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  48 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03169799999999867
# Elapsed time during the u/v gridding value calculation in seconds: 0.01708399999999699
# FFT the  48 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  49 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.026198999999998307
# Elapsed time during the u/v gridding value calculation in seconds: 0.016225999999996077
# FFT the  49 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  50 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0249290000000002
# Elapsed time during the u/v gridding value calculation in seconds: 0.013452999999998383
# FFT the  50 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  51 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.02366100000000415
# Elapsed time during the u/v gridding value calculation in seconds: 0.019019999999997594
# FFT the  51 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  52 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.021892000000008238
# Elapsed time during the u/v gridding value calculation in seconds: 0.012016000000002691
# FFT the  52 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  53 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.018711999999993623
# Elapsed time during the u/v gridding value calculation in seconds: 0.015189000000006558
# FFT the  53 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  54 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.01693900000000781
# Elapsed time during the u/v gridding value calculation in seconds: 0.013153000000002635
# FFT the  54 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  55 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.016593000000000302
# Elapsed time during the u/v gridding value calculation in seconds: 0.011274999999997704
# FFT the  55 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  56 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.011732999999992444
# Elapsed time during the u/v gridding value calculation in seconds: 0.009303000000002726
# FFT the  56 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  57 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.008797999999998751
# Elapsed time during the u/v gridding value calculation in seconds: 0.007268000000010488
# FFT the  57 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  58 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.006560000000007449
# Elapsed time during the u/v gridding value calculation in seconds: 0.004657999999992057
# FFT the  58 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  59 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.006860000000003197
# Elapsed time during the u/v gridding value calculation in seconds: 0.00513300000000072
# FFT the  59 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  60 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0030859999999961474
# Elapsed time during the u/v gridding value calculation in seconds: 0.0025880000000029213
# FFT the  60 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  61 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.005482000000000653
# Elapsed time during the u/v gridding value calculation in seconds: 0.003803000000004886
# FFT the  61 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  62 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.007587999999998374
# Elapsed time during the u/v gridding value calculation in seconds: 0.004187000000001717
# FFT the  62 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  63 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.007446999999999093
# Elapsed time during the u/v gridding value calculation in seconds: 0.0042439999999999145
# FFT the  63 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  64 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00818599999999492
# Elapsed time during the u/v gridding value calculation in seconds: 0.0056409999999971205
# FFT the  64 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  65 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0085679999999968
# Elapsed time during the u/v gridding value calculation in seconds: 0.0048160000000052605
# FFT the  65 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  66 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00796900000000278
# Elapsed time during the u/v gridding value calculation in seconds: 0.00645099999999843
# FFT the  66 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  67 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.006582999999992012
# Elapsed time during the u/v gridding value calculation in seconds: 0.005404999999996107
# FFT the  67 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  68 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0036860000000018545
# Elapsed time during the u/v gridding value calculation in seconds: 0.003246000000004301
# FFT the  68 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  69 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.004494999999991478
# Elapsed time during the u/v gridding value calculation in seconds: 0.0032020000000017035
# FFT the  69 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  70 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0018040000000070222
# Elapsed time during the u/v gridding value calculation in seconds: 0.0015290000000049986
# FFT the  70 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  71 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0021700000000066666
# Elapsed time during the u/v gridding value calculation in seconds: 0.0017179999999967777
# FFT the  71 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  72 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0011540000000138662
# Elapsed time during the u/v gridding value calculation in seconds: 0.0015219999999942502
# FFT the  72 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  73 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0007880000000000109
# Elapsed time during the u/v gridding value calculation in seconds: 0.0007170000000087384
# FFT the  73 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  74 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0004670000000004393
# Elapsed time during the u/v gridding value calculation in seconds: 0.0003829999999993561
# FFT the  74 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  75 th level facet out of  76  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00037700000000029377
# Elapsed time during the u/v gridding value calculation in seconds: 0.00025499999999567535
# FFT the  75 th level facet out of  76  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Elapsed time during the uv-gridding calculation in seconds: 82.539424

# %% [markdown]
# #### Rescale and have a look

# %%
I_image_now = image_rescale(I_image,im_size, n_uv)
B_image_now = image_rescale(B_image,im_size, n_uv)
plt.figure()
plt.imshow(np.rot90(I_image_now.real,1), origin = 'lower')
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
B_image_now[150,150]
# Out:
# <img src="data:image/png;base64,..." width="640">
# (1.000000002275519+0j)

# %% [markdown]
# #### Correcting functions h(x)h(y) on x and y axis

# %% [markdown]
# #### W= 6, x0 = 0.25

# %%
Nfft = 600
# Use these for calculating gridding correction on the FFT grid
M = 32
I_xycorrected = xy_correct(I_image_now, W, M, h, im_size, x0=0.25)
B_xycorrected = xy_correct(B_image_now, W, M, h, im_size, x0=0.25)

# %% [markdown]
# #### Correcting function on z axis

# %%
Cor_gridz = z_correct_cal(X_min, X_max, Y_min, Y_max, dw, h, im_size, W, M, x0)
I_zcorrected = z_correct(I_xycorrected, Cor_gridz, im_size, x0=0.25)
B_zcorrected = z_correct(B_xycorrected, Cor_gridz, im_size, x0=0.25)

# %% [markdown]
# ### 4 DFT and FFT dirty image difference

# %%
I_DFT = np.loadtxt('I_DFT_simul300.csv', delimiter = ',')

# %%
I_dif = I_DFT - I_zcorrected.real
rms = RMS(I_dif, im_size, 0.5, x0=0.25)
plt.figure()
plt.imshow(np.rot90(I_dif,1), origin = 'lower')
plt.colorbar()
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print (rms)
# Out:
# 3.124313037059876e-07
