# %% [markdown]
# ## Reference:
#
# Ye, H. (2019). Accurate image reconstruction in radio interferometry (Doctoral thesis). https://doi.org/10.17863/CAM.39448
#
# Haoyang Ye, Stephen F Gull, Sze M Tan, Bojan Nikolic, Optimal gridding and degridding in radio interferometry imaging, Monthly Notices of the Royal Astronomical Society, Volume 491, Issue 1, January 2020, Pages 1146–1159, https://doi.org/10.1093/mnras/stz2970
#
# Github: https://github.com/zoeye859/Imaging-Tutorial

# %%
# %matplotlib notebook
import numpy as np
from scipy.optimize import leastsq, brent
from scipy.linalg import solve_triangular
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from time import process_time
from numpy.linalg import inv
np.set_printoptions(precision=16)
from Imaging_core import *
from Gridding_core import *
import pickle
with open("min_misfit_gridding_7.pkl", "rb") as pp:
    opt_funcs = pickle.load(pp)

# %% [markdown]
# ### 1. Read in the data

# %%
#########  Read in visibilities ##########
data = np.genfromtxt('simul3d.csv', delimiter = ',')
jj = complex(0,1)
u_original = data.T[2][1:]
v_original = data.T[3][1:]
w_original = data.T[4][1:]
V_original = data.T[5][1:] + jj*data.T[6][1:]
n_uv = len(u_original)
uv_max = max(np.sqrt(u_original**2+v_original**2))
V,u,v,w = Visibility_minusw(V_original,u_original,v_original,w_original)

#### Determine the pixel size ####
X_size = 300 # image size on x-axis
Y_size = 300 # image size on y-axis
X_min = -1.15/2 #You can change X_min and X_max in order to change the pixel size.
X_max = 1.15/2
X = np.linspace(X_min, X_max, num=X_size+1)[0:X_size]
Y_min = -1.15/2 #You can change Y_min and Y_max in order to change the pixel size.
Y_max = 1.15/2
Y = np.linspace(Y_min,Y_max,num=Y_size+1)[0:Y_size]
pixel_resol_x = 180. * 60. * 60. * (X_max - X_min) / np.pi / X_size
pixel_resol_y = 180. * 60. * 60. * (Y_max - Y_min) / np.pi / Y_size
print ("The pixel size on x-axis is ", pixel_resol_x, " arcsec")
# Out:
# The pixel size on x-axis is  790.681757280536  arcsec

# %% [markdown]
# ### 2. determine the number of w planes
#
# Here is a short introduction to the original W-Stacking method (Offringa, 2014). Starting from
#
# $V(u,v,w) = \int\int \frac{\text{d}l \text{d}m }{\sqrt{1-l^2-m^2}}I(l,m)\exp\left[-i2\pi\left(ul+vm+w\left(\sqrt{1-l^2-m^2}-1\right)\right)\right]	$
#
# The right-hand side can be separated into one part without any $w$-term and the rest which contains the $w$-term. For each given non--zero $w_i$, we have
#
# $V(u,v,w_i) = \int \int \mathrm{d}l \mathrm{d}m \frac{I(l,m)}{\sqrt{1-l^2-m^2}} \exp{[-i2\pi(ul+vm)]}\exp{\Big\{-i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
#
# For each given non-zero $w_i$, this is essentially a two--dimensional Fourier transform. By inverting the transform, we have:
#
# $\frac{I(l,m)}{\sqrt{1-l^2-m^2}} = \int \int \mathrm{d}u \mathrm{d}v V(u,v,w_i)\exp{[i2\pi(ul+vm)]}	\exp{\Big\{i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\} $
#
# If we integrate both sides along the $w$-axis from the minimum $w_{\rm min}$ to the maximum $w_{\rm max}$ on the right-hand side, the result is
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \int_{w_{\rm min}}^{w_{\rm max}} \mathrm{d}w \exp{\Big\{\mathrm{i}2\pi\Big[w\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
# $\int \int \mathrm{d}u \mathrm{d}v V(u,v,w)\exp{[i2\pi(ul+vm)]}$
#
# In practice, the values of $w$ are discretised into $N_w$ uniform samples along the $w$-axis,  can be written as:
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \sum_{n = 0}^{N_w-1}\exp{\Big\{i2\pi\Big[w_n\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}\int \int \mathrm{d}u \mathrm{d}v V(u,v,w_n)\exp{[i2\pi(ul+vm)]} $
#
# Following (Offringa, 2014), the separation of two subsequent $w$ values $\delta w$ should satisfy the criterion:
#
# $|\delta w 2\pi(\sqrt{1-l^2-m^2}-1)| \ll 1$
#
# If $\delta w$ is larger than this, more $w$ samples are needed. Hence, $N_w$ is determined by:
#
# $N_w \geq 2\pi(w_{\rm max} - w_{\rm min})\max_{l,m}(1-\sqrt{1-l^2-m^2})$

# %% [markdown]
# ### 2.1 Redetermin the number of w planes
#
# <img src="normalised_coordinate.png">
#
# In the normalised coordinate system plotted above, the field of view is confined in the region of $[-0.5,0.5]$. $x_0$ and $y_0$ represents how much of the image will be cropped after the FFT process （Ye,2019 on optimal gridding and degridding）. Here we have $x_0 = y_0$. The angular size of the map required for the FFT in $l$ is $l_{\rm range}/(2x_0)$, and is $N_x$ pixels. If $u$ is specified in wavelengths, it is multiplied by $l_{\rm range}/(2x_0)$ to convert to pixels, so that we redetermin the number of $w$-planes as:
#
# $N_x \geq (u_{\rm max}-u_{\rm min})l_{\rm range}/x_0$
#
# We now consider the choice of the $w$ or $z$ grid. We set the phase centre $z=0$ at $n=0$ and $z=-x_0$ at $n_{\rm min}$. In our improved W-Stacking, we do not apply FFT in the $z$ direction, so there is no advantage in oversampling the beam considerably. Consequently,
#
# $N_z \geq (w_{\rm max}-w_{\rm min})n_{\rm min}/x_0$
#
# The number of $w$-planes using least-misfit gridding function can therefore be determined as:
#
# $N_{w'} \equiv N_z \geq\frac{\max_{l,m}(1-\sqrt{1-l^2-m^2})(w_{\rm max} - w_{\rm min})}{x_0} + W$
#
# The additional $w$-planes enable visibilities located close to the top or bottom $w$-planes to be gridded to grids on both sides.
#
# The number of $w$-planes, $N_{w}$, determined by the original W-Stacking method is more than 1.5 times greater than the first part of $N_{w'}$. Thus, for given data, the improved W-Stacking method may require fewer $w$--planes than the original W-Stacking method. $x_0 = 0.25, W\geq 7$ is recommended so as to achieve the single precision limit in the image misfit level.

# %% [markdown]
# ### 2. Determine w plane number Nw_2R

# %%
W = 6
x0=0.25
Nw_2R, w_values, dw = Wplanes(W, X_max, Y_max, w, x0)
# Out:
# We will have 75 w-planes

# %% [markdown]
# ### 3 3D Gridding + Imaging + Correcting
#
# To know more about gridding, you can refer to https://github.com/zoeye859/Imaging-Tutorial
# #### Calculating gridding values for w respectively

# %%
Nfft = 600
im_size = 600
W = 6
M, x0, h = opt_funcs[W].M, opt_funcs[W].x0, opt_funcs[W].h
ind = find_nearestw(w_values, w)
C_w = cal_grid_w(w, w_values, ind, dw, W, h, M)
# Out:
# Elapsed time during the w gridding value calculation in seconds: 0.9198950000000001

# %% [markdown]
# #### Gridding on w-axis

# %%
def grid_w(V, u, v, w, C_w, w_values, W, Nw_2R, idx):
    """
    Grid on w-axis
    Args:
        V (np.narray): visibility data
        u (np.narray): u of the (u,v,w) coordinates
        v (np.narray): v of the (u,v,w) coordinates
        w (np.narray): w of the (u,v,w) coordinates
        Nw_2R (int): number of w-planes used
        W (int): support width of the gridding function
        w_values (list): w values for all w-planes would be formed
        idx (list): the index of the nearest w plane that this w value would be assigned to
        dw (float): difference between two neighbouring w-planes
        C_w (list): the list of gridding weights for the w array
    """
    n_uv = len(V)
    bEAM = np.ones(n_uv)
    V_wgrid = np.zeros((Nw_2R,1),dtype = np.complex_).tolist()
    beam_wgrid = np.zeros((Nw_2R,1),dtype = np.complex_).tolist()
    u_wgrid = np.zeros((Nw_2R,1)).tolist()
    v_wgrid = np.zeros((Nw_2R,1)).tolist()
    t_start = process_time() 
    idx_floor = find_floorw(w_values, w)

    for k in range(n_uv):
        C_wk = C_w[k]
        if W % 2 == 1:
            w_plane = idx[k]
        else:
            w_plane = idx_floor[k]
        j = 0
        for n in range(-W//2+1,-W//2+1+W):
            print (k, w_plane+n, C_wk[j,0], V[k])
            V_wgrid[w_plane+n] += [C_wk[j,0] * V[k]]
            u_wgrid[w_plane+n] += [u[k]]
            v_wgrid[w_plane+n] += [v[k]]
            beam_wgrid[w_plane+n] += [C_wk[j,0] * bEAM[k]]
            j+=1

    for i in range(Nw_2R):
        del(V_wgrid[i][0])
        del(u_wgrid[i][0])
        del(v_wgrid[i][0])
        del(beam_wgrid[i][0])

    t_stop = process_time()   
    print("Elapsed time during the w-gridding calculation in seconds:", t_stop-t_start)   
    return V_wgrid, u_wgrid, v_wgrid, beam_wgrid

def find_floorw(w_values, w):
    """
    For each w value, find the index of the nearest w plane on the left that this w value would be gridded to
    Args:
        w_values (list): w values for all w-planes would be formed
        w (float): w of the (u,v,w) coordinates
    Returns:
        idx (list): the index of the nearest w plane that this w value would be gridded to
    """
    w_values = np.asarray(w_values)
    idx= np.searchsorted(w_values, w, side="left")
    return idx-1

# %%
V_wgrid, u_wgrid, v_wgrid, beam_wgrid = grid_w(V, u, v, w, C_w, w_values, W, Nw_2R, ind)
# Out:
# Elapsed time during the w-gridding calculation in seconds: 0.15917700000000012

# %%
V_wgrid
# Out:
# [[(0.035191291524651364-0.0015111405955133043j),
#   (-0.010165863162320085-0.009838830566221372j),
#   (-1.2543123155718054+5.050768480719773j),
#   (0.027159000363919453-0.007251874911676231j),
#   (1.0542875703856476-0.45560678412549693j),
#   (-0.13836588637039676+0.70725314346831j),
#   (-4.5842401053517445-0.5060503210500904j),
#   (-0.013067311653423886-0.03037454080755758j),
#   (3.010590613496584e-05+0.004741469557345922j)],
#  [(0.1514004724890707+0.13199841739649912j),
#   (-0.4301236787704457-0.41628673634206415j),
#   (-2.315867108170567+9.32535577485043j),
#   (3.646641129808074-1.5758835489295295j),
#   (-0.04796813951242659+0.24518772904524613j),
#   (-0.6801144969417618-0.07507725416179772j)],
#  [(-1.9191619942977536-1.8574231611748082j),
#   (-1.0172134400782558+4.096036941939495j),
#   (2.921354688373794-1.2624534825664933j),
#   (-0.0024923856399778075+0.01273975562076635j),
#   (-0.006146848894695107-0.000678545360871358j)],
#  [(-1.9191619942977547-1.857423161174809j),
#   (-0.07676924489499215+0.30912849821419663j),
#   (0.5002973345954504-0.21620178983824426j)],
#  [(-0.4301236787704447-0.4162867363420632j),
#   (0.006533707519237321-0.0028235194598447283j)],
#  [(-0.010165863162319334-0.009838830566220645j),
#   (0.039812680170481764-0.032258861851424306j)]]

# %% [markdown]
# #### Imaging

# %%
I_size = int(im_size*2*x0)
V_grid = np.zeros((im_size,im_size),dtype = np.complex_)
B_grid = np.zeros((im_size,im_size),dtype = np.complex_) 
I_image = np.zeros((I_size,I_size),dtype = np.complex_)
B_image = np.zeros((I_size,I_size),dtype = np.complex_)
R = W//2

t2_start = process_time() 
for w_ind in range(Nw_2R):
    print ('Gridding the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    V_update = np.asarray(V_wgrid[w_ind])
    u_update = np.asarray(u_wgrid[w_ind])
    v_update = np.asarray(v_wgrid[w_ind])
    beam_update = np.asarray(beam_wgrid[w_ind])
    C_u, u_grid = cal_grid_uv(u_update, W, im_size, X_max, X_min, h, M, x0=0.25)
    C_v, v_grid = cal_grid_uv(v_update, W, im_size, Y_max, Y_min, h, M, x0=0.25)
    for k in range(0,len(V_wgrid[w_ind])):
        C_uk = C_u[k]
        C_vk = C_v[k]
        u_index = np.int(np.floor(u_grid[k]))
        v_index = np.int(np.floor(v_grid[k]))
        for m in range(-R+1,R+1):
            for n in range(-R+1,R+1):
                V_grid[u_index+m,v_index+n] += C_uk[m+R-1] * C_vk[n+R-1] * V_update[k]
                B_grid[u_index+m,v_index+n] += C_uk[m+R-1] * C_vk[n+R-1] * beam_update[k]
    print ('FFT the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    I_image += FFTnPShift(V_grid, w_values[w_ind], X, Y, im_size, x0)
    B_image += FFTnPShift(B_grid, w_values[w_ind], X, Y, im_size, x0)
    B_grid = np.zeros((im_size,im_size),dtype = np.complex_) 
    V_grid = np.zeros((im_size,im_size),dtype = np.complex_)
    
t2_stop = process_time()   
print("Elapsed time during the uv-gridding calculation in seconds:", t2_stop-t2_start)
# Out:
# Gridding the  0 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.047870999999999775
# Elapsed time during the u/v gridding value calculation in seconds: 0.038272000000000084
# FFT the  0 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  1 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07991599999999988
# Elapsed time during the u/v gridding value calculation in seconds: 0.07286999999999999
# FFT the  1 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  2 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.11480099999999993
# Elapsed time during the u/v gridding value calculation in seconds: 0.11381300000000039
# FFT the  2 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  3 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14694399999999952
# Elapsed time during the u/v gridding value calculation in seconds: 0.15451000000000015
# FFT the  3 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  4 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.17609400000000086
# Elapsed time during the u/v gridding value calculation in seconds: 0.18634899999999988
# FFT the  4 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  5 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.19983599999999946
# Elapsed time during the u/v gridding value calculation in seconds: 0.20539300000000082
# FFT the  5 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  6 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.2089800000000004
# Elapsed time during the u/v gridding value calculation in seconds: 0.2054980000000004
# FFT the  6 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  7 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.20236300000000007
# Elapsed time during the u/v gridding value calculation in seconds: 0.20599699999999999
# FFT the  7 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  8 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1955840000000002
# Elapsed time during the u/v gridding value calculation in seconds: 0.19879200000000097
# FFT the  8 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  9 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.2001659999999994
# Elapsed time during the u/v gridding value calculation in seconds: 0.1984819999999985
# FFT the  9 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  10 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1947259999999993
# Elapsed time during the u/v gridding value calculation in seconds: 0.20187600000000216
# FFT the  10 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  11 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.19374600000000086
# Elapsed time during the u/v gridding value calculation in seconds: 0.19358300000000028
# FFT the  11 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  12 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.19338300000000075
# Elapsed time during the u/v gridding value calculation in seconds: 0.19480799999999832
# FFT the  12 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  13 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.18141199999999813
# Elapsed time during the u/v gridding value calculation in seconds: 0.1873909999999981
# FFT the  13 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  14 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.17943599999999904
# Elapsed time during the u/v gridding value calculation in seconds: 0.1895920000000011
# FFT the  14 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  15 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1945660000000018
# Elapsed time during the u/v gridding value calculation in seconds: 0.18317799999999806
# FFT the  15 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  16 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.20151900000000111
# Elapsed time during the u/v gridding value calculation in seconds: 0.20376100000000008
# FFT the  16 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  17 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.18330900000000128
# Elapsed time during the u/v gridding value calculation in seconds: 0.17880699999999905
# FFT the  17 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  18 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.17031499999999866
# Elapsed time during the u/v gridding value calculation in seconds: 0.17745500000000192
# FFT the  18 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  19 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.16130799999999823
# Elapsed time during the u/v gridding value calculation in seconds: 0.17043499999999767
# FFT the  19 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  20 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15025500000000136
# Elapsed time during the u/v gridding value calculation in seconds: 0.15911400000000242
# FFT the  20 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  21 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.148142
# Elapsed time during the u/v gridding value calculation in seconds: 0.15990599999999944
# FFT the  21 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  22 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15790499999999952
# Elapsed time during the u/v gridding value calculation in seconds: 0.14672999999999803
# FFT the  22 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  23 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1348389999999995
# Elapsed time during the u/v gridding value calculation in seconds: 0.14864200000000238
# FFT the  23 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  24 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.12736900000000162
# Elapsed time during the u/v gridding value calculation in seconds: 0.12785800000000336
# FFT the  24 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  25 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1182449999999946
# Elapsed time during the u/v gridding value calculation in seconds: 0.12335499999999655
# FFT the  25 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  26 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.11281300000000272
# Elapsed time during the u/v gridding value calculation in seconds: 0.116533000000004
# FFT the  26 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  27 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.10392399999999924
# Elapsed time during the u/v gridding value calculation in seconds: 0.09642900000000054
# FFT the  27 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  28 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1054499999999976
# Elapsed time during the u/v gridding value calculation in seconds: 0.09843800000000158
# FFT the  28 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  29 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09486100000000164
# Elapsed time during the u/v gridding value calculation in seconds: 0.0930929999999961
# FFT the  29 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  30 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0969869999999986
# Elapsed time during the u/v gridding value calculation in seconds: 0.08888100000000065
# FFT the  30 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  31 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09873000000000332
# Elapsed time during the u/v gridding value calculation in seconds: 0.09066399999999675
# FFT the  31 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  32 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09220100000000286
# Elapsed time during the u/v gridding value calculation in seconds: 0.08754199999999912
# FFT the  32 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  33 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08903300000000058
# Elapsed time during the u/v gridding value calculation in seconds: 0.08965500000000048
# FFT the  33 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  34 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08579799999999693
# Elapsed time during the u/v gridding value calculation in seconds: 0.08186399999999594
# FFT the  34 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  35 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07629299999999972
# Elapsed time during the u/v gridding value calculation in seconds: 0.07695700000000016
# FFT the  35 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  36 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.06992600000000238
# Elapsed time during the u/v gridding value calculation in seconds: 0.06466000000000349
# FFT the  36 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  37 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07221799999999945
# Elapsed time during the u/v gridding value calculation in seconds: 0.06340200000000351
# FFT the  37 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  38 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.06468500000000432
# Elapsed time during the u/v gridding value calculation in seconds: 0.05473599999999834
# FFT the  38 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  39 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.050651999999999475
# Elapsed time during the u/v gridding value calculation in seconds: 0.04677499999999668
# FFT the  39 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  40 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.04892600000000158
# Elapsed time during the u/v gridding value calculation in seconds: 0.04339999999999833
# FFT the  40 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  41 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.04887599999999992
# Elapsed time during the u/v gridding value calculation in seconds: 0.03949200000000275
# FFT the  41 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  42 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.043124000000005935
# Elapsed time during the u/v gridding value calculation in seconds: 0.03624699999999592
# FFT the  42 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  43 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.04408799999999502
# Elapsed time during the u/v gridding value calculation in seconds: 0.02971600000000052
# FFT the  43 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  44 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0347020000000029
# Elapsed time during the u/v gridding value calculation in seconds: 0.029831000000001495
# FFT the  44 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  45 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.04032800000000236
# Elapsed time during the u/v gridding value calculation in seconds: 0.031493999999995026
# FFT the  45 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  46 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03293599999999941
# Elapsed time during the u/v gridding value calculation in seconds: 0.029895000000003336
# FFT the  46 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  47 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03258499999999742
# Elapsed time during the u/v gridding value calculation in seconds: 0.02565299999999837
# FFT the  47 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  48 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.034065000000012446
# Elapsed time during the u/v gridding value calculation in seconds: 0.02348699999998871
# FFT the  48 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  49 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.02938499999999067
# Elapsed time during the u/v gridding value calculation in seconds: 0.02458599999999933
# FFT the  49 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  50 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03171199999999885
# Elapsed time during the u/v gridding value calculation in seconds: 0.02019599999999855
# FFT the  50 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  51 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.02499000000000251
# Elapsed time during the u/v gridding value calculation in seconds: 0.018126999999992677
# FFT the  51 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  52 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.025251999999994723
# Elapsed time during the u/v gridding value calculation in seconds: 0.02139900000000239
# FFT the  52 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  53 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.025068999999987795
# Elapsed time during the u/v gridding value calculation in seconds: 0.01347299999999052
# FFT the  53 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  54 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.01939000000000135
# Elapsed time during the u/v gridding value calculation in seconds: 0.011873999999991725
# FFT the  54 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  55 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.020584999999996967
# Elapsed time during the u/v gridding value calculation in seconds: 0.01194700000000637
# FFT the  55 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  56 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.011592999999990639
# Elapsed time during the u/v gridding value calculation in seconds: 0.00727399999999534
# FFT the  56 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  57 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.013810999999989804
# Elapsed time during the u/v gridding value calculation in seconds: 0.009532999999990466
# FFT the  57 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  58 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.009341000000006261
# Elapsed time during the u/v gridding value calculation in seconds: 0.006878999999997859
# FFT the  58 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  59 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.009647999999998547
# Elapsed time during the u/v gridding value calculation in seconds: 0.0049730000000067776
# FFT the  59 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  60 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.007892000000012445
# Elapsed time during the u/v gridding value calculation in seconds: 0.0046500000000122554
# FFT the  60 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  61 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.008438999999995644
# Elapsed time during the u/v gridding value calculation in seconds: 0.004260999999999626
# FFT the  61 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  62 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.009407999999993422
# Elapsed time during the u/v gridding value calculation in seconds: 0.00524799999999459
# FFT the  62 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  63 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.009531000000009726
# Elapsed time during the u/v gridding value calculation in seconds: 0.006354000000001747
# FFT the  63 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  64 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.008302000000000476
# Elapsed time during the u/v gridding value calculation in seconds: 0.00751499999999794
# FFT the  64 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  65 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.010546999999988316
# Elapsed time during the u/v gridding value calculation in seconds: 0.00684400000000096
# FFT the  65 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  66 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.012422000000000821
# Elapsed time during the u/v gridding value calculation in seconds: 0.006648000000012644
# FFT the  66 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  67 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00963199999999631
# Elapsed time during the u/v gridding value calculation in seconds: 0.0055490000000020245
# FFT the  67 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  68 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.007928000000006818
# Elapsed time during the u/v gridding value calculation in seconds: 0.0047190000000085774
# FFT the  68 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  69 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.004526999999995951
# Elapsed time during the u/v gridding value calculation in seconds: 0.003619999999997958
# FFT the  69 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  70 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.005459999999999354
# Elapsed time during the u/v gridding value calculation in seconds: 0.003551000000001636
# FFT the  70 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  71 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0040690000000012105
# Elapsed time during the u/v gridding value calculation in seconds: 0.003652000000002431
# FFT the  71 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  72 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0026250000000089813
# Elapsed time during the u/v gridding value calculation in seconds: 0.0021469999999936817
# FFT the  72 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  73 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0019900000000063756
# Elapsed time during the u/v gridding value calculation in seconds: 0.001992000000001326
# FFT the  73 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  74 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.001729000000011638
# Elapsed time during the u/v gridding value calculation in seconds: 0.0015290000000049986
# FFT the  74 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Elapsed time during the uv-gridding calculation in seconds: 82.664569

# %% [markdown]
# #### Rescale and have a look

# %%
I_image_now = image_rescale(I_image,im_size, n_uv)
B_image_now = image_rescale(B_image,im_size, n_uv)
plt.figure()
plt.imshow(np.rot90(I_image_now.real,1), origin = 'lower')
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
B_image_now[150,150]
# Out:
# <img src="data:image/png;base64,..." width="640">
# (1.000000005590356+0j)

# %% [markdown]
# #### Correcting functions h(x)h(y) on x and y axis

# %% [markdown]
# #### W= 6, x0 = 0.25

# %%
Nfft = 600
# Use these for calculating gridding correction on the FFT grid
M = 32
I_xycorrected = xy_correct(I_image_now, opt_funcs[6], im_size, x0=0.25)
B_xycorrected = xy_correct(B_image_now, opt_funcs[6], im_size, x0=0.25)

# %% [markdown]
# #### Correcting function on z axis

# %%
Cor_gridz = z_correct_cal(X_min, X_max, Y_min, Y_max, dw, h, im_size, W, M, x0)
I_zcorrected = z_correct(I_xycorrected, Cor_gridz, im_size, x0=0.25)
B_zcorrected = z_correct(B_xycorrected, Cor_gridz, im_size, x0=0.25)

# %% [markdown]
# ### 4 DFT and FFT dirty image difference

# %%
I_DFT = np.loadtxt('I_DFT_simul300.csv', delimiter = ',')

# %%
I_dif = I_DFT - I_zcorrected.real
rms = RMS(I_dif, im_size, 0.5, x0=0.25)
plt.figure()
plt.imshow(np.rot90(I_dif,1), origin = 'lower')
plt.colorbar()
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print (rms)
# Out:
# 3.1153852973496086e-07
