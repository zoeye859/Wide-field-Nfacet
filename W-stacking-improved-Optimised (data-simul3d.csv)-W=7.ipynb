# %% [markdown]
# ## Reference:
#
# Ye, H. (2019). Accurate image reconstruction in radio interferometry (Doctoral thesis). https://doi.org/10.17863/CAM.39448
#
# Haoyang Ye, Stephen F Gull, Sze M Tan, Bojan Nikolic, Optimal gridding and degridding in radio interferometry imaging, Monthly Notices of the Royal Astronomical Society, Volume 491, Issue 1, January 2020, Pages 1146–1159, https://doi.org/10.1093/mnras/stz2970
#
# Github: https://github.com/zoeye859/Imaging-Tutorial

# %%
# %matplotlib notebook
import numpy as np
from scipy.optimize import leastsq, brent
from scipy.linalg import solve_triangular
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from time import process_time
from numpy.linalg import inv
np.set_printoptions(precision=16)
from Imaging_core import *
from Gridding_core import *
import pickle
with open("min_misfit_gridding_7.pkl", "rb") as pp:
    opt_funcs = pickle.load(pp)

# %% [markdown]
# ### 1. Read in the data

# %%
#########  Read in visibilities ##########
data = np.genfromtxt('simul3d.csv', delimiter = ',')
jj = complex(0,1)
u_original = data.T[2][1:]
v_original = data.T[3][1:]
w_original = data.T[4][1:]
V_original = data.T[5][1:] + jj*data.T[6][1:]
n_uv = len(u_original)
uv_max = max(np.sqrt(u_original**2+v_original**2))
V,u,v,w = Visibility_minusw(V_original,u_original,v_original,w_original)

#### Determine the pixel size ####
X_size = 300 # image size on x-axis
Y_size = 300 # image size on y-axis
X_min = -1.15/2 #You can change X_min and X_max in order to change the pixel size.
X_max = 1.15/2
X = np.linspace(X_min, X_max, num=X_size+1)[0:X_size]
Y_min = -1.15/2 #You can change Y_min and Y_max in order to change the pixel size.
Y_max = 1.15/2
Y = np.linspace(Y_min,Y_max,num=Y_size+1)[0:Y_size]
pixel_resol_x = 180. * 60. * 60. * (X_max - X_min) / np.pi / X_size
pixel_resol_y = 180. * 60. * 60. * (Y_max - Y_min) / np.pi / Y_size
print ("The pixel size on x-axis is ", pixel_resol_x, " arcsec")
# Out:
# The pixel size on x-axis is  790.681757280536  arcsec

# %% [markdown]
# ### 2. determine the number of w planes
#
# Here is a short introduction to the original W-Stacking method (Offringa, 2014). Starting from
#
# $V(u,v,w) = \int\int \frac{\text{d}l \text{d}m }{\sqrt{1-l^2-m^2}}I(l,m)\exp\left[-i2\pi\left(ul+vm+w\left(\sqrt{1-l^2-m^2}-1\right)\right)\right]	$
#
# The right-hand side can be separated into one part without any $w$-term and the rest which contains the $w$-term. For each given non--zero $w_i$, we have
#
# $V(u,v,w_i) = \int \int \mathrm{d}l \mathrm{d}m \frac{I(l,m)}{\sqrt{1-l^2-m^2}} \exp{[-i2\pi(ul+vm)]}\exp{\Big\{-i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
#
# For each given non-zero $w_i$, this is essentially a two--dimensional Fourier transform. By inverting the transform, we have:
#
# $\frac{I(l,m)}{\sqrt{1-l^2-m^2}} = \int \int \mathrm{d}u \mathrm{d}v V(u,v,w_i)\exp{[i2\pi(ul+vm)]}	\exp{\Big\{i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\} $
#
# If we integrate both sides along the $w$-axis from the minimum $w_{\rm min}$ to the maximum $w_{\rm max}$ on the right-hand side, the result is
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \int_{w_{\rm min}}^{w_{\rm max}} \mathrm{d}w \exp{\Big\{\mathrm{i}2\pi\Big[w\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
# $\int \int \mathrm{d}u \mathrm{d}v V(u,v,w)\exp{[i2\pi(ul+vm)]}$
#
# In practice, the values of $w$ are discretised into $N_w$ uniform samples along the $w$-axis,  can be written as:
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \sum_{n = 0}^{N_w-1}\exp{\Big\{i2\pi\Big[w_n\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}\int \int \mathrm{d}u \mathrm{d}v V(u,v,w_n)\exp{[i2\pi(ul+vm)]} $
#
# Following (Offringa, 2014), the separation of two subsequent $w$ values $\delta w$ should satisfy the criterion:
#
# $|\delta w 2\pi(\sqrt{1-l^2-m^2}-1)| \ll 1$
#
# If $\delta w$ is larger than this, more $w$ samples are needed. Hence, $N_w$ is determined by:
#
# $N_w \geq 2\pi(w_{\rm max} - w_{\rm min})\max_{l,m}(1-\sqrt{1-l^2-m^2})$

# %% [markdown]
# ### 2.1 Redetermin the number of w planes
#
# <img src="normalised_coordinate.png">
#
# In the normalised coordinate system plotted above, the field of view is confined in the region of $[-0.5,0.5]$. $x_0$ and $y_0$ represents how much of the image will be cropped after the FFT process （Ye,2019 on optimal gridding and degridding）. Here we have $x_0 = y_0$. The angular size of the map required for the FFT in $l$ is $l_{\rm range}/(2x_0)$, and is $N_x$ pixels. If $u$ is specified in wavelengths, it is multiplied by $l_{\rm range}/(2x_0)$ to convert to pixels, so that we redetermin the number of $w$-planes as:
#
# $N_x \geq (u_{\rm max}-u_{\rm min})l_{\rm range}/x_0$
#
# We now consider the choice of the $w$ or $z$ grid. We set the phase centre $z=0$ at $n=0$ and $z=-x_0$ at $n_{\rm min}$. In our improved W-Stacking, we do not apply FFT in the $z$ direction, so there is no advantage in oversampling the beam considerably. Consequently,
#
# $N_z \geq (w_{\rm max}-w_{\rm min})n_{\rm min}/x_0$
#
# The number of $w$-planes using least-misfit gridding function can therefore be determined as:
#
# $N_{w'} \equiv N_z \geq\frac{\max_{l,m}(1-\sqrt{1-l^2-m^2})(w_{\rm max} - w_{\rm min})}{x_0} + W$
#
# The additional $w$-planes enable visibilities located close to the top or bottom $w$-planes to be gridded to grids on both sides.
#
# The number of $w$-planes, $N_{w}$, determined by the original W-Stacking method is more than 1.5 times greater than the first part of $N_{w'}$. Thus, for given data, the improved W-Stacking method may require fewer $w$--planes than the original W-Stacking method. $x_0 = 0.25, W\geq 7$ is recommended so as to achieve the single precision limit in the image misfit level.

# %% [markdown]
# ### 2. Determine w plane number Nw_2R

# %%
W = 7
x0=0.25
Nw_2R, w_values, dw = Wplanes(W, X_max, Y_max, w, x0)
# Out:
# We will have 77 w-planes

# %% [markdown]
# ### 3 3D Gridding + Imaging + Correcting
#
# To know more about gridding, you can refer to https://github.com/zoeye859/Imaging-Tutorial
# #### Calculating gridding values for w respectively: use W = 7

# %%
Nfft = 600
im_size = 600
W = 7
M, x0, h = opt_funcs[W].M, opt_funcs[W].x0, opt_funcs[W].h
ind = find_nearestw(w_values, w)
C_w = cal_grid_w(w, w_values, ind, dw, W, h, M)
# Out:
# /Users/yehaoyang/Documents/Wide-field-Nfacet/Gridding_core.py:48: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
# Elapsed time during the w gridding value calculation in seconds: 0.8977119999999998

# %%
for k in range(10):
    print ((w[k] - w_values[ind[k]])/dw)
# Out:
# 0.41868924982159794
# 0.7905483333822867
# 0.6158093958129376
# 0.200069723733769
# 0.20628800546146003
# 0.39718819401908345
# 0.01725098655396537
# 0.38910506693523406
# 0.2143711325453061
# 0.1704872165534273

# %%
a = calc_C(h, x0, np.asarray([0.1]), W)
plt.figure()
plt.plot(a)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Gridding on w-axis

# %%
bEAM = np.ones(n_uv)
V_wgrid = np.zeros((Nw_2R,1),dtype = np.complex_).tolist()
beam_wgrid = np.zeros((Nw_2R,1),dtype = np.complex_).tolist()
u_wgrid = np.zeros((Nw_2R,1)).tolist()
v_wgrid = np.zeros((Nw_2R,1)).tolist()
R = W//2
t2_start = process_time() 

for k in range(n_uv):
    C_wk = C_w[k]
    w_plane = ind[k]
    for n in range(-R+1,R+1):
        V_wgrid[w_plane+n] += [C_wk[n+R-1,0] * V[k]]
        u_wgrid[w_plane+n] += [u[k]]
        v_wgrid[w_plane+n] += [v[k]]
        beam_wgrid[w_plane+n] += [C_wk[n+R-1,0] * bEAM[k]]

t2_stop = process_time()   
print("Elapsed time during the w-gridding calculation in seconds:", t2_stop-t2_start)
# Out:
# Elapsed time during the w-gridding calculation in seconds: 0.16740700000000075

# %%
for i in range(Nw_2R):
    del(V_wgrid[i][0])
    del(u_wgrid[i][0])
    del(v_wgrid[i][0])
    del(beam_wgrid[i][0])

# %% [markdown]
# #### Imaging

# %%
I_size = int(im_size*2*x0)
V_grid = np.zeros((im_size,im_size),dtype = np.complex_)
B_grid = np.zeros((im_size,im_size),dtype = np.complex_) 
I_image = np.zeros((I_size,I_size),dtype = np.complex_)
B_image = np.zeros((I_size,I_size),dtype = np.complex_)


t2_start = process_time() 
for w_ind in range(Nw_2R):
    print ('Gridding the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    V_update = np.asarray(V_wgrid[w_ind])
    u_update = np.asarray(u_wgrid[w_ind])
    v_update = np.asarray(v_wgrid[w_ind])
    beam_update = np.asarray(beam_wgrid[w_ind])
    C_u, u_grid = cal_grid_uv(u_update, W, im_size, X_max, X_min, h, x0=0.25)
    C_v, v_grid = cal_grid_uv(v_update, W, im_size, Y_max, Y_min, h, x0=0.25)
    for k in range(0,len(V_wgrid[w_ind])):
        C_uk = C_u[k]
        C_vk = C_v[k]
        u_index = np.int(np.floor(u_grid[k]))
        v_index = np.int(np.floor(v_grid[k]))
        for m in range(-R+1,R+1):
            for n in range(-R+1,R+1):
                V_grid[u_index+m,v_index+n] += C_uk[m+R-1] * C_vk[n+R-1] * V_update[k]
                B_grid[u_index+m,v_index+n] += C_uk[m+R-1] * C_vk[n+R-1] * beam_update[k]
    print ('FFT the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    I_image += FFTnPShift(V_grid, w_values[w_ind], X, Y, im_size, x0)
    B_image += FFTnPShift(B_grid, w_values[w_ind], X, Y, im_size, x0)
    B_grid = np.zeros((im_size,im_size),dtype = np.complex_) 
    V_grid = np.zeros((im_size,im_size),dtype = np.complex_)
    
t2_stop = process_time()   
print("Elapsed time during the uv-gridding calculation in seconds:", t2_stop-t2_start)
# Out:
# Gridding the  0 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0007530000000004478
# Elapsed time during the u/v gridding value calculation in seconds: 0.0005910000000000082
# FFT the  0 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  1 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.042914999999999814
# Elapsed time during the u/v gridding value calculation in seconds: 0.03238800000000008
# FFT the  1 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  2 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07576299999999936
# Elapsed time during the u/v gridding value calculation in seconds: 0.06120899999999985
# FFT the  2 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  3 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.10003699999999949
# Elapsed time during the u/v gridding value calculation in seconds: 0.09930400000000006
# FFT the  3 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  4 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14146700000000045
# Elapsed time during the u/v gridding value calculation in seconds: 0.13328899999999955
# FFT the  4 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  5 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.17214799999999997
# Elapsed time during the u/v gridding value calculation in seconds: 0.16588600000000042
# FFT the  5 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  6 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1890009999999993
# Elapsed time during the u/v gridding value calculation in seconds: 0.2006920000000001
# FFT the  6 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  7 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.18946299999999994
# Elapsed time during the u/v gridding value calculation in seconds: 0.19231100000000012
# FFT the  7 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  8 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.18581499999999984
# Elapsed time during the u/v gridding value calculation in seconds: 0.19247299999999967
# FFT the  8 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  9 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.18554100000000062
# Elapsed time during the u/v gridding value calculation in seconds: 0.18147799999999847
# FFT the  9 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  10 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1806049999999999
# Elapsed time during the u/v gridding value calculation in seconds: 0.18197100000000077
# FFT the  10 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  11 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.178526999999999
# Elapsed time during the u/v gridding value calculation in seconds: 0.1732830000000014
# FFT the  11 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  12 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.176912999999999
# Elapsed time during the u/v gridding value calculation in seconds: 0.1796900000000008
# FFT the  12 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  13 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.16816100000000134
# Elapsed time during the u/v gridding value calculation in seconds: 0.17929900000000032
# FFT the  13 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  14 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.16658899999999832
# Elapsed time during the u/v gridding value calculation in seconds: 0.1630420000000008
# FFT the  14 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  15 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.2005410000000012
# Elapsed time during the u/v gridding value calculation in seconds: 0.18930099999999683
# FFT the  15 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  16 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.182933000000002
# Elapsed time during the u/v gridding value calculation in seconds: 0.17938000000000187
# FFT the  16 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  17 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1800619999999995
# Elapsed time during the u/v gridding value calculation in seconds: 0.1834200000000017
# FFT the  17 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  18 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15297600000000244
# Elapsed time during the u/v gridding value calculation in seconds: 0.15604500000000243
# FFT the  18 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  19 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15894300000000072
# Elapsed time during the u/v gridding value calculation in seconds: 0.14929400000000115
# FFT the  19 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  20 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1478919999999988
# Elapsed time during the u/v gridding value calculation in seconds: 0.15702399999999983
# FFT the  20 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  21 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1417550000000034
# Elapsed time during the u/v gridding value calculation in seconds: 0.13734300000000133
# FFT the  21 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  22 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.13376600000000138
# Elapsed time during the u/v gridding value calculation in seconds: 0.13555999999999813
# FFT the  22 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  23 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.12947499999999934
# Elapsed time during the u/v gridding value calculation in seconds: 0.13517399999999924
# FFT the  23 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  24 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.12012
# Elapsed time during the u/v gridding value calculation in seconds: 0.12530300000000238
# FFT the  24 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  25 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.11421399999999693
# Elapsed time during the u/v gridding value calculation in seconds: 0.12011000000000394
# FFT the  25 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  26 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.10900800000000288
# Elapsed time during the u/v gridding value calculation in seconds: 0.0951300000000046
# FFT the  26 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  27 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.10279700000000247
# Elapsed time during the u/v gridding value calculation in seconds: 0.0958000000000041
# FFT the  27 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  28 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09902500000000458
# Elapsed time during the u/v gridding value calculation in seconds: 0.08829899999999924
# FFT the  28 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  29 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08911200000000008
# Elapsed time during the u/v gridding value calculation in seconds: 0.08829699999999718
# FFT the  29 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  30 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09212200000000337
# Elapsed time during the u/v gridding value calculation in seconds: 0.08294300000000021
# FFT the  30 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  31 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09187200000000217
# Elapsed time during the u/v gridding value calculation in seconds: 0.08634500000000145
# FFT the  31 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  32 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0910909999999987
# Elapsed time during the u/v gridding value calculation in seconds: 0.07745299999999844
# FFT the  32 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  33 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08657800000000293
# Elapsed time during the u/v gridding value calculation in seconds: 0.07112800000000163
# FFT the  33 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  34 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08720899999999432
# Elapsed time during the u/v gridding value calculation in seconds: 0.07489699999999999
# FFT the  34 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  35 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07628199999999907
# Elapsed time during the u/v gridding value calculation in seconds: 0.0664289999999994
# FFT the  35 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  36 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0779190000000014
# Elapsed time during the u/v gridding value calculation in seconds: 0.06918300000000244
# FFT the  36 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  37 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07183299999999804
# Elapsed time during the u/v gridding value calculation in seconds: 0.06175299999999595
# FFT the  37 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  38 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.061053000000001134
# Elapsed time during the u/v gridding value calculation in seconds: 0.055528000000002464
# FFT the  38 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  39 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.05594200000000171
# Elapsed time during the u/v gridding value calculation in seconds: 0.04861700000000013
# FFT the  39 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  40 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.05095199999999522
# Elapsed time during the u/v gridding value calculation in seconds: 0.043137000000001535
# FFT the  40 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  41 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.04866700000000179
# Elapsed time during the u/v gridding value calculation in seconds: 0.037649999999999295
# FFT the  41 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  42 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.045225999999999544
# Elapsed time during the u/v gridding value calculation in seconds: 0.030878000000001293
# FFT the  42 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  43 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.040554999999997676
# Elapsed time during the u/v gridding value calculation in seconds: 0.03747200000000106
# FFT the  43 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  44 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.038090000000003954
# Elapsed time during the u/v gridding value calculation in seconds: 0.03388199999999841
# FFT the  44 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  45 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03973799999999983
# Elapsed time during the u/v gridding value calculation in seconds: 0.02669699999999864
# FFT the  45 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  46 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.04017800000000449
# Elapsed time during the u/v gridding value calculation in seconds: 0.026336999999998056
# FFT the  46 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  47 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.036448000000000036
# Elapsed time during the u/v gridding value calculation in seconds: 0.029710999999998933
# FFT the  47 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  48 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03166500000000383
# Elapsed time during the u/v gridding value calculation in seconds: 0.023975999999997555
# FFT the  48 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  49 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03549499999999739
# Elapsed time during the u/v gridding value calculation in seconds: 0.02135299999999063
# FFT the  49 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  50 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.02918499999999824
# Elapsed time during the u/v gridding value calculation in seconds: 0.021666999999993664
# FFT the  50 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  51 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.029218999999997664
# Elapsed time during the u/v gridding value calculation in seconds: 0.018129000000001838
# FFT the  51 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  52 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.024371999999999616
# Elapsed time during the u/v gridding value calculation in seconds: 0.016047000000000367
# FFT the  52 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  53 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.025246999999993136
# Elapsed time during the u/v gridding value calculation in seconds: 0.014564999999990391
# FFT the  53 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  54 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.01950300000000027
# Elapsed time during the u/v gridding value calculation in seconds: 0.01401599999999803
# FFT the  54 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  55 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.019577999999995654
# Elapsed time during the u/v gridding value calculation in seconds: 0.01064399999999921
# FFT the  55 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  56 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.016877000000008024
# Elapsed time during the u/v gridding value calculation in seconds: 0.01287600000000566
# FFT the  56 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  57 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.011842999999998938
# Elapsed time during the u/v gridding value calculation in seconds: 0.01188799999999901
# FFT the  57 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  58 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.011854999999997062
# Elapsed time during the u/v gridding value calculation in seconds: 0.008078999999995062
# FFT the  58 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  59 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.009444999999999482
# Elapsed time during the u/v gridding value calculation in seconds: 0.0053000000000054115
# FFT the  59 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  60 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0072040000000015425
# Elapsed time during the u/v gridding value calculation in seconds: 0.004080999999999335
# FFT the  60 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  61 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0056179999999983465
# Elapsed time during the u/v gridding value calculation in seconds: 0.003844999999998322
# FFT the  61 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  62 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0059079999999909205
# Elapsed time during the u/v gridding value calculation in seconds: 0.004176000000001068
# FFT the  62 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  63 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00841200000000697
# Elapsed time during the u/v gridding value calculation in seconds: 0.004286999999990826
# FFT the  63 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  64 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.006822999999997137
# Elapsed time during the u/v gridding value calculation in seconds: 0.005274999999997476
# FFT the  64 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  65 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.009472000000002367
# Elapsed time during the u/v gridding value calculation in seconds: 0.006602000000000885
# FFT the  65 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  66 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.007340999999996711
# Elapsed time during the u/v gridding value calculation in seconds: 0.006301999999990926
# FFT the  66 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  67 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00867900000000077
# Elapsed time during the u/v gridding value calculation in seconds: 0.0055669999999992115
# FFT the  67 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  68 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.007561999999992963
# Elapsed time during the u/v gridding value calculation in seconds: 0.004806999999999562
# FFT the  68 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  69 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.007559999999998013
# Elapsed time during the u/v gridding value calculation in seconds: 0.005332999999993149
# FFT the  69 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  70 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.005378000000007432
# Elapsed time during the u/v gridding value calculation in seconds: 0.0038060000000115224
# FFT the  70 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  71 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0019759999999990896
# Elapsed time during the u/v gridding value calculation in seconds: 0.001898999999994544
# FFT the  71 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  72 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0024599999999992406
# Elapsed time during the u/v gridding value calculation in seconds: 0.0020690000000058717
# FFT the  72 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  73 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0009560000000021773
# Elapsed time during the u/v gridding value calculation in seconds: 0.0009230000000002292
# FFT the  73 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  74 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0019929999999988013
# Elapsed time during the u/v gridding value calculation in seconds: 0.001889999999988845
# FFT the  74 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  75 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.001508000000001175
# Elapsed time during the u/v gridding value calculation in seconds: 0.00046299999999632746
# FFT the  75 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  76 th level facet out of  77  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 4.400000000259752e-05
# Elapsed time during the u/v gridding value calculation in seconds: 2.4999999993724487e-05
# FFT the  76 th level facet out of  77  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Elapsed time during the uv-gridding calculation in seconds: 82.21132

# %% [markdown]
# #### Rescale and have a look

# %%
I_image_now = image_rescale(I_image,im_size, n_uv)
B_image_now = image_rescale(B_image,im_size, n_uv)
plt.figure()
plt.imshow(np.rot90(I_image_now.real,1), origin = 'lower')
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
B_image_now[150,150]
# Out:
# <img src="data:image/png;base64,..." width="640">
# (15321565836.918077+0j)

# %% [markdown]
# #### Correcting functions h(x)h(y) on x and y axis

# %% [markdown]
# #### W= 6, x0 = 0.25

# %%
Nfft = 600
# Use these for calculating gridding correction on the FFT grid
M = 32
I_xycorrected = xy_correct(I_image_now, W, M, h, im_size, x0=0.25)
B_xycorrected = xy_correct(B_image_now, W, M, h, im_size, x0=0.25)

# %% [markdown]
# #### Correcting function on z axis

# %%
Cor_gridz = z_correct_cal(X_min, X_max, Y_min, Y_max, dw, h, im_size, W, M, x0)
I_zcorrected = z_correct(I_xycorrected, Cor_gridz, im_size, x0=0.25)
B_zcorrected = z_correct(B_xycorrected, Cor_gridz, im_size, x0=0.25)

# %% [markdown]
# ### 4 DFT and FFT dirty image difference

# %%
I_DFT = np.loadtxt('I_DFT_simul300.csv', delimiter = ',')

# %%
I_dif = I_DFT - I_zcorrected.real
rms = RMS(I_dif, im_size, 0.5, x0=0.25)
plt.figure()
plt.imshow(np.rot90(I_dif,1), origin = 'lower')
plt.colorbar()
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print (rms)
# Out:
# 3.124313037059876e-07
