# %% [markdown]
# ## Reference:
#
# Ye, H. (2019). Accurate image reconstruction in radio interferometry (Doctoral thesis). https://doi.org/10.17863/CAM.39448
#
# Haoyang Ye, Stephen F Gull, Sze M Tan, Bojan Nikolic, Optimal gridding and degridding in radio interferometry imaging, Monthly Notices of the Royal Astronomical Society, Volume 491, Issue 1, January 2020, Pages 1146–1159, https://doi.org/10.1093/mnras/stz2970
#
# Github: https://github.com/zoeye859/Imaging-Tutorial

# %%
# %matplotlib notebook
import numpy as np
from scipy.optimize import leastsq, brent
from scipy.linalg import solve_triangular
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from time import process_time
from numpy.linalg import inv
np.set_printoptions(precision=16)
from Imaging_core_new import *
from Gridding_core import *
import pickle
with open("min_misfit_gridding_14.pkl", "rb") as pp:
    opt_funcs = pickle.load(pp)

# %% [markdown]
# ### 1. Read in the data

# %%
#########  Read in visibilities ##########
data = np.genfromtxt('simul3d.csv', delimiter = ',')
jj = complex(0,1)
u_original = data.T[2][1:]
v_original = data.T[3][1:]
w_original = data.T[4][1:]
V_original = data.T[5][1:] + jj*data.T[6][1:]
n_uv = len(u_original)
uv_max = max(np.sqrt(u_original**2+v_original**2))
V,u,v,w = Visibility_minusw(V_original,u_original,v_original,w_original)

#### Determine the pixel size ####
X_size = 300 # image size on x-axis
Y_size = 300 # image size on y-axis
X_min = -1.15/2 #You can change X_min and X_max in order to change the pixel size.
X_max = 1.15/2
X = np.linspace(X_min, X_max, num=X_size+1)[0:X_size]
Y_min = -1.15/2 #You can change Y_min and Y_max in order to change the pixel size.
Y_max = 1.15/2
Y = np.linspace(Y_min,Y_max,num=Y_size+1)[0:Y_size]
pixel_resol_x = 180. * 60. * 60. * (X_max - X_min) / np.pi / X_size
pixel_resol_y = 180. * 60. * 60. * (Y_max - Y_min) / np.pi / Y_size
print ("The pixel size on x-axis is ", pixel_resol_x, " arcsec")
# Out:
# The pixel size on x-axis is  790.681757280536  arcsec

# %% [markdown]
# ### 2. determine the number of w planes
#
# Here is a short introduction to the original W-Stacking method (Offringa, 2014). Starting from
#
# $V(u,v,w) = \int\int \frac{\text{d}l \text{d}m }{\sqrt{1-l^2-m^2}}I(l,m)\exp\left[-i2\pi\left(ul+vm+w\left(\sqrt{1-l^2-m^2}-1\right)\right)\right]	$
#
# The right-hand side can be separated into one part without any $w$-term and the rest which contains the $w$-term. For each given non--zero $w_i$, we have
#
# $V(u,v,w_i) = \int \int \mathrm{d}l \mathrm{d}m \frac{I(l,m)}{\sqrt{1-l^2-m^2}} \exp{[-i2\pi(ul+vm)]}\exp{\Big\{-i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
#
# For each given non-zero $w_i$, this is essentially a two--dimensional Fourier transform. By inverting the transform, we have:
#
# $\frac{I(l,m)}{\sqrt{1-l^2-m^2}} = \int \int \mathrm{d}u \mathrm{d}v V(u,v,w_i)\exp{[i2\pi(ul+vm)]}	\exp{\Big\{i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\} $
#
# If we integrate both sides along the $w$-axis from the minimum $w_{\rm min}$ to the maximum $w_{\rm max}$ on the right-hand side, the result is
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \int_{w_{\rm min}}^{w_{\rm max}} \mathrm{d}w \exp{\Big\{\mathrm{i}2\pi\Big[w\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
# $\int \int \mathrm{d}u \mathrm{d}v V(u,v,w)\exp{[i2\pi(ul+vm)]}$
#
# In practice, the values of $w$ are discretised into $N_w$ uniform samples along the $w$-axis,  can be written as:
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \sum_{n = 0}^{N_w-1}\exp{\Big\{i2\pi\Big[w_n\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}\int \int \mathrm{d}u \mathrm{d}v V(u,v,w_n)\exp{[i2\pi(ul+vm)]} $
#
# Following (Offringa, 2014), the separation of two subsequent $w$ values $\delta w$ should satisfy the criterion:
#
# $|\delta w 2\pi(\sqrt{1-l^2-m^2}-1)| \ll 1$
#
# If $\delta w$ is larger than this, more $w$ samples are needed. Hence, $N_w$ is determined by:
#
# $N_w \geq 2\pi(w_{\rm max} - w_{\rm min})\max_{l,m}(1-\sqrt{1-l^2-m^2})$

# %% [markdown]
# ### 2.1 Redetermin the number of w planes
#
# <img src="normalised_coordinate.png">
#
# In the normalised coordinate system plotted above, the field of view is confined in the region of $[-0.5,0.5]$. $x_0$ and $y_0$ represents how much of the image will be cropped after the FFT process （Ye,2019 on optimal gridding and degridding）. Here we have $x_0 = y_0$. The angular size of the map required for the FFT in $l$ is $l_{\rm range}/(2x_0)$, and is $N_x$ pixels. If $u$ is specified in wavelengths, it is multiplied by $l_{\rm range}/(2x_0)$ to convert to pixels, so that we redetermin the number of $w$-planes as:
#
# $N_x \geq (u_{\rm max}-u_{\rm min})l_{\rm range}/x_0$
#
# We now consider the choice of the $w$ or $z$ grid. We set the phase centre $z=0$ at $n=0$ and $z=-x_0$ at $n_{\rm min}$. In our improved W-Stacking, we do not apply FFT in the $z$ direction, so there is no advantage in oversampling the beam considerably. Consequently,
#
# $N_z \geq (w_{\rm max}-w_{\rm min})n_{\rm min}/x_0$
#
# The number of $w$-planes using least-misfit gridding function can therefore be determined as:
#
# $N_{w'} \equiv N_z \geq\frac{\max_{l,m}(1-\sqrt{1-l^2-m^2})(w_{\rm max} - w_{\rm min})}{x_0} + W$
#
# The additional $w$-planes enable visibilities located close to the top or bottom $w$-planes to be gridded to grids on both sides.
#
# The number of $w$-planes, $N_{w}$, determined by the original W-Stacking method is more than 1.5 times greater than the first part of $N_{w'}$. Thus, for given data, the improved W-Stacking method may require fewer $w$--planes than the original W-Stacking method. $x_0 = 0.25, W\geq 7$ is recommended so as to achieve the single precision limit in the image misfit level.

# %% [markdown]
# ### 2. Determine w plane number Nw_2R

# %%
W = 14
M, x0, h = opt_funcs[W].M, opt_funcs[W].x0, opt_funcs[W].h

Nw_2R, w_values, dw = Wplanes(W, X_max, Y_max, w, x0)
# Out:
# We will have 83 w-planes

# %% [markdown]
# ### 3 3D Gridding + Imaging + Correcting
#
# To know more about gridding, you can refer to https://github.com/zoeye859/Imaging-Tutorial
# #### Calculating gridding values for w respectively

# %%
Nfft = 600
im_size = 600

ind = find_nearestw(w_values, w)
C_w = cal_grid_w(w, w_values, ind, dw, W, h, M)
# Out:
# Elapsed time during the w gridding value calculation in seconds: 1.3245399999999998

# %% [markdown]
# #### Gridding on w-axis

# %%
V_wgrid, u_wgrid, v_wgrid, beam_wgrid = grid_w(V, u, v, w, C_w, w_values, W, Nw_2R, ind)
# Out:
# Elapsed time during the w-gridding calculation in seconds: 0.32907300000000017

# %% [markdown]
# #### Imaging

# %%
I_size = int(im_size*2*x0)
I_image = np.zeros((I_size,I_size),dtype = np.complex_)
B_image = np.zeros((I_size,I_size),dtype = np.complex_)

t2_start = process_time() 
for w_ind in range(Nw_2R):
    print ('Gridding the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    V_update = np.asarray(V_wgrid[w_ind])
    u_update = np.asarray(u_wgrid[w_ind])
    v_update = np.asarray(v_wgrid[w_ind])
    beam_update = np.asarray(beam_wgrid[w_ind])
    V_grid, B_grid = grid_uv(V_update, u_update, v_update, beam_update, W, im_size, X_max, X_min, Y_max, Y_min, h, M)
    print ('FFT the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    I_image += FFTnPShift(V_grid, w_values[w_ind], X, Y, im_size, x0)
    B_image += FFTnPShift(B_grid, w_values[w_ind], X, Y, im_size, x0)
    B_grid = np.zeros((im_size,im_size),dtype = np.complex_) 
    V_grid = np.zeros((im_size,im_size),dtype = np.complex_)
    
t2_stop = process_time()   
print("Elapsed time during imaging in seconds:", t2_stop-t2_start)
# Out:
# Gridding the  0 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.05580400000000019
# Elapsed time during the u/v gridding value calculation in seconds: 0.05285699999999993
# FFT the  0 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  1 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.10051200000000016
# Elapsed time during the u/v gridding value calculation in seconds: 0.10275299999999987
# FFT the  1 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  2 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14301299999999983
# Elapsed time during the u/v gridding value calculation in seconds: 0.16052200000000028
# FFT the  2 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  3 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.19501299999999944
# Elapsed time during the u/v gridding value calculation in seconds: 0.21047899999999942
# FFT the  3 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  4 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.253914
# Elapsed time during the u/v gridding value calculation in seconds: 0.25919300000000156
# FFT the  4 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  5 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.29992599999999925
# Elapsed time during the u/v gridding value calculation in seconds: 0.3034579999999991
# FFT the  5 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  6 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.34046499999999824
# Elapsed time during the u/v gridding value calculation in seconds: 0.3517430000000026
# FFT the  6 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  7 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.39215599999999995
# Elapsed time during the u/v gridding value calculation in seconds: 0.39226899999999887
# FFT the  7 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  8 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.4342170000000003
# Elapsed time during the u/v gridding value calculation in seconds: 0.46402300000000096
# FFT the  8 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  9 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.4799509999999998
# Elapsed time during the u/v gridding value calculation in seconds: 0.4867910000000002
# FFT the  9 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  10 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.5879109999999983
# Elapsed time during the u/v gridding value calculation in seconds: 0.5846900000000019
# FFT the  10 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  11 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.564148000000003
# Elapsed time during the u/v gridding value calculation in seconds: 0.5652290000000022
# FFT the  11 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  12 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.609815999999995
# Elapsed time during the u/v gridding value calculation in seconds: 0.6112639999999985
# FFT the  12 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  13 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.6336080000000024
# Elapsed time during the u/v gridding value calculation in seconds: 0.6460620000000006
# FFT the  13 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  14 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.6417500000000018
# Elapsed time during the u/v gridding value calculation in seconds: 0.6365139999999982
# FFT the  14 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  15 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.6372519999999966
# Elapsed time during the u/v gridding value calculation in seconds: 0.628067999999999
# FFT the  15 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  16 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.6081849999999918
# Elapsed time during the u/v gridding value calculation in seconds: 0.6136819999999972
# FFT the  16 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  17 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.5931300000000022
# Elapsed time during the u/v gridding value calculation in seconds: 0.6294430000000091
# FFT the  17 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  18 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.6026219999999967
# Elapsed time during the u/v gridding value calculation in seconds: 0.5905580000000015
# FFT the  18 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  19 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.5906279999999953
# Elapsed time during the u/v gridding value calculation in seconds: 0.5760900000000078
# FFT the  19 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  20 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.5776079999999979
# Elapsed time during the u/v gridding value calculation in seconds: 0.5616930000000053
# FFT the  20 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  21 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.5367030000000028
# Elapsed time during the u/v gridding value calculation in seconds: 0.5593709999999987
# FFT the  21 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  22 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.5200590000000034
# Elapsed time during the u/v gridding value calculation in seconds: 0.5288240000000002
# FFT the  22 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  23 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.4983970000000113
# Elapsed time during the u/v gridding value calculation in seconds: 0.5090380000000039
# FFT the  23 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  24 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.48101700000000847
# Elapsed time during the u/v gridding value calculation in seconds: 0.49516700000000924
# FFT the  24 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  25 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.4629460000000023
# Elapsed time during the u/v gridding value calculation in seconds: 0.471935000000002
# FFT the  25 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  26 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.4635990000000021
# Elapsed time during the u/v gridding value calculation in seconds: 0.4473780000000005
# FFT the  26 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  27 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.4207789999999818
# Elapsed time during the u/v gridding value calculation in seconds: 0.4178919999999948
# FFT the  27 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  28 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.4022460000000194
# Elapsed time during the u/v gridding value calculation in seconds: 0.41458900000000654
# FFT the  28 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  29 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.37388999999998873
# Elapsed time during the u/v gridding value calculation in seconds: 0.3923860000000161
# FFT the  29 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  30 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.35887800000000425
# Elapsed time during the u/v gridding value calculation in seconds: 0.36914200000001074
# FFT the  30 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  31 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.3468079999999816
# Elapsed time during the u/v gridding value calculation in seconds: 0.3550960000000032
# FFT the  31 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  32 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.3437849999999969
# Elapsed time during the u/v gridding value calculation in seconds: 0.3536269999999888
# FFT the  32 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  33 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.3094910000000084
# Elapsed time during the u/v gridding value calculation in seconds: 0.31687400000001276
# FFT the  33 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  34 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.3018780000000163
# Elapsed time during the u/v gridding value calculation in seconds: 0.3051279999999963
# FFT the  34 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  35 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.2904869999999846
# Elapsed time during the u/v gridding value calculation in seconds: 0.280965000000009
# FFT the  35 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  36 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.25930599999998094
# Elapsed time during the u/v gridding value calculation in seconds: 0.2818889999999783
# FFT the  36 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  37 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.24656899999999382
# Elapsed time during the u/v gridding value calculation in seconds: 0.2548919999999839
# FFT the  37 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  38 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.23521300000001588
# Elapsed time during the u/v gridding value calculation in seconds: 0.24030500000000643
# FFT the  38 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  39 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.21306999999998766
# Elapsed time during the u/v gridding value calculation in seconds: 0.23784299999999803
# FFT the  39 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  40 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1964930000000038
# Elapsed time during the u/v gridding value calculation in seconds: 0.20748900000000958
# FFT the  40 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  41 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1825669999999775
# Elapsed time during the u/v gridding value calculation in seconds: 0.2015519999999924
# FFT the  41 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  42 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1680470000000014
# Elapsed time during the u/v gridding value calculation in seconds: 0.19291599999999676
# FFT the  42 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  43 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.16391500000000292
# Elapsed time during the u/v gridding value calculation in seconds: 0.17435199999999895
# FFT the  43 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  44 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14327800000000934
# Elapsed time during the u/v gridding value calculation in seconds: 0.16507400000000416
# FFT the  44 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  45 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.13258200000001352
# Elapsed time during the u/v gridding value calculation in seconds: 0.14766700000001265
# FFT the  45 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  46 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.12079299999999193
# Elapsed time during the u/v gridding value calculation in seconds: 0.13366999999999507
# FFT the  46 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  47 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.10940500000000952
# Elapsed time during the u/v gridding value calculation in seconds: 0.11876899999998614
# FFT the  47 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  48 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0983749999999759
# Elapsed time during the u/v gridding value calculation in seconds: 0.10777799999999615
# FFT the  48 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  49 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08922400000000152
# Elapsed time during the u/v gridding value calculation in seconds: 0.08977799999999547
# FFT the  49 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  50 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08577999999999975
# Elapsed time during the u/v gridding value calculation in seconds: 0.08341200000000981
# FFT the  50 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  51 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07314400000001342
# Elapsed time during the u/v gridding value calculation in seconds: 0.07521900000000414
# FFT the  51 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  52 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.06594200000000683
# Elapsed time during the u/v gridding value calculation in seconds: 0.0685320000000047
# FFT the  52 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  53 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.06411300000002029
# Elapsed time during the u/v gridding value calculation in seconds: 0.06390199999998458
# FFT the  53 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  54 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.05632299999999191
# Elapsed time during the u/v gridding value calculation in seconds: 0.06025099999999384
# FFT the  54 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  55 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.04959399999998482
# Elapsed time during the u/v gridding value calculation in seconds: 0.055367999999987205
# FFT the  55 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  56 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0484000000000151
# Elapsed time during the u/v gridding value calculation in seconds: 0.0463579999999979
# FFT the  56 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  57 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.047635999999982914
# Elapsed time during the u/v gridding value calculation in seconds: 0.04473200000001043
# FFT the  57 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  58 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03343699999999217
# Elapsed time during the u/v gridding value calculation in seconds: 0.03697800000000484
# FFT the  58 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  59 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.030262999999990825
# Elapsed time during the u/v gridding value calculation in seconds: 0.03417900000002305
# FFT the  59 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  60 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.025065000000012105
# Elapsed time during the u/v gridding value calculation in seconds: 0.027825000000007094
# FFT the  60 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  61 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.02051300000002243
# Elapsed time during the u/v gridding value calculation in seconds: 0.023502999999976737
# FFT the  61 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  62 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.018449000000003934
# Elapsed time during the u/v gridding value calculation in seconds: 0.0221909999999923
# FFT the  62 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  63 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.019574000000005753
# Elapsed time during the u/v gridding value calculation in seconds: 0.021308000000004768
# FFT the  63 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  64 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.01587500000002251
# Elapsed time during the u/v gridding value calculation in seconds: 0.016376000000008162
# FFT the  64 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  65 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.017065999999999804
# Elapsed time during the u/v gridding value calculation in seconds: 0.019170000000002574
# FFT the  65 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  66 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.012897000000009484
# Elapsed time during the u/v gridding value calculation in seconds: 0.014475000000004457
# FFT the  66 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  67 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.010653999999988173
# Elapsed time during the u/v gridding value calculation in seconds: 0.0115650000000187
# FFT the  67 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  68 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.011327999999991789
# Elapsed time during the u/v gridding value calculation in seconds: 0.011474999999990132
# FFT the  68 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  69 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.008558999999991102
# Elapsed time during the u/v gridding value calculation in seconds: 0.010110999999994874
# FFT the  69 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  70 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.009347000000019534
# Elapsed time during the u/v gridding value calculation in seconds: 0.009591999999997824
# FFT the  70 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  71 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00970599999999422
# Elapsed time during the u/v gridding value calculation in seconds: 0.008724000000000842
# FFT the  71 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  72 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00851799999998093
# Elapsed time during the u/v gridding value calculation in seconds: 0.009496999999981881
# FFT the  72 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  73 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.007093999999995049
# Elapsed time during the u/v gridding value calculation in seconds: 0.007886000000013382
# FFT the  73 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  74 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00595599999999763
# Elapsed time during the u/v gridding value calculation in seconds: 0.009436999999991258
# FFT the  74 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  75 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.006479999999982056
# Elapsed time during the u/v gridding value calculation in seconds: 0.00674000000000774
# FFT the  75 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  76 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.004362000000014632
# Elapsed time during the u/v gridding value calculation in seconds: 0.006888000000003558
# FFT the  76 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  77 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.003011000000014974
# Elapsed time during the u/v gridding value calculation in seconds: 0.006679999999988695
# FFT the  77 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  78 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0022720000000049367
# Elapsed time during the u/v gridding value calculation in seconds: 0.002636999999992895
# FFT the  78 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  79 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0026490000000194414
# Elapsed time during the u/v gridding value calculation in seconds: 0.002135000000009768
# FFT the  79 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  80 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0013219999999876109
# Elapsed time during the u/v gridding value calculation in seconds: 0.0018760000000099808
# FFT the  80 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  81 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0008640000000070813
# Elapsed time during the u/v gridding value calculation in seconds: 0.0012270000000000891
# FFT the  81 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  82 th level facet out of  83  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.001524999999986676
# Elapsed time during the u/v gridding value calculation in seconds: 0.0012810000000058608
# FFT the  82 th level facet out of  83  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Elapsed time during imaging in seconds: 222.226882

# %% [markdown]
# #### Rescale and have a look

# %%
I_image_now = image_rescale(I_image,im_size, n_uv)
B_image_now = image_rescale(B_image,im_size, n_uv)
plt.figure()
plt.imshow(np.rot90(I_image_now.real,1), origin = 'lower')
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
B_image_now[150,150]
# Out:
# <img src="data:image/png;base64,..." width="640">
# (1+0j)

# %% [markdown]
# #### Correcting functions h(x)h(y) on x and y axis

# %% [markdown]
# #### W= 14, x0 = 0.25

# %%
Nfft = 600
# Use these for calculating gridding correction on the FFT grid
M = 32
I_xycorrected = xy_correct(I_image_now, opt_funcs[W], im_size, x0=0.25)
B_xycorrected = xy_correct(B_image_now, opt_funcs[W], im_size, x0=0.25)

# %%
plt.figure()
plt.imshow(np.rot90(I_xycorrected.real,1), origin = 'lower')
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
B_image_now[150,150]
# Out:
# <img src="data:image/png;base64,..." width="640">
# (1+0j)

# %% [markdown]
# #### Correcting function on z axis

# %%
lut = setup_lookup_table(opt_funcs[14], Nfine=256, degree=7, x0=0.25) # set up routine, 7-order interplation
Cor_gridz = z_correct_cal(lut, X_min, X_max, Y_min, Y_max, dw, h, im_size, W, M, x0)
I_zcorrected = z_correct(I_xycorrected, Cor_gridz, im_size, x0=0.25)
B_zcorrected = z_correct(B_xycorrected, Cor_gridz, im_size, x0=0.25)

# %%
plt.figure()
plt.imshow(np.rot90(I_zcorrected.real,1), origin = 'lower')
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
B_image_now[150,150]
# Out:
# <img src="data:image/png;base64,..." width="1600">
# (1+0j)

# %% [markdown]
# ### 4 DFT and FFT dirty image difference

# %%
I_DFT = np.loadtxt('I_DFT_simul300.csv', delimiter = ',')

# %%
I_dif = I_DFT - I_zcorrected.real
rms = RMS(I_dif, im_size, 0.5, x0=0.25)
plt.figure()
plt.imshow(np.rot90(I_dif,1), origin = 'lower')
plt.colorbar()
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print (rms)
# Out:
# 2.7528542844819584e-15
