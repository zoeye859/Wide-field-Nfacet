# %% [markdown]
# ## Reference:
#
# Ye, H. (2019). Accurate image reconstruction in radio interferometry (Doctoral thesis). https://doi.org/10.17863/CAM.39448
#
# Haoyang Ye, Stephen F Gull, Sze M Tan, Bojan Nikolic, Optimal gridding and degridding in radio interferometry imaging, Monthly Notices of the Royal Astronomical Society, Volume 491, Issue 1, January 2020, Pages 1146–1159, https://doi.org/10.1093/mnras/stz2970
#
# Github: https://github.com/zoeye859/Imaging-Tutorial

# %%
# %matplotlib notebook
import numpy as np
from scipy.optimize import leastsq, brent
from scipy.linalg import solve_triangular
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from time import process_time
from numpy.linalg import inv
np.set_printoptions(precision=16)
from Imaging_core_new import *
from Gridding_core import *
import pickle
with open("min_misfit_gridding_7.pkl", "rb") as pp:
    opt_funcs = pickle.load(pp)

# %% [markdown]
# ### 1. Read in the data

# %%
#########  Read in visibilities ##########
data = np.genfromtxt('simul3d.csv', delimiter = ',')
jj = complex(0,1)
u_original = data.T[2][1:]
v_original = data.T[3][1:]
w_original = data.T[4][1:]
V_original = data.T[5][1:] + jj*data.T[6][1:]
n_uv = len(u_original)
uv_max = max(np.sqrt(u_original**2+v_original**2))
V,u,v,w = Visibility_minusw(V_original,u_original,v_original,w_original)

#### Determine the pixel size ####
X_size = 300 # image size on x-axis
Y_size = 300 # image size on y-axis
X_min = -1.15/2 #You can change X_min and X_max in order to change the pixel size.
X_max = 1.15/2
X = np.linspace(X_min, X_max, num=X_size+1)[0:X_size]
Y_min = -1.15/2 #You can change Y_min and Y_max in order to change the pixel size.
Y_max = 1.15/2
Y = np.linspace(Y_min,Y_max,num=Y_size+1)[0:Y_size]
pixel_resol_x = 180. * 60. * 60. * (X_max - X_min) / np.pi / X_size
pixel_resol_y = 180. * 60. * 60. * (Y_max - Y_min) / np.pi / Y_size
print ("The pixel size on x-axis is ", pixel_resol_x, " arcsec")
# Out:
# The pixel size on x-axis is  790.681757280536  arcsec

# %% [markdown]
# ### 2. determine the number of w planes
#
# Here is a short introduction to the original W-Stacking method (Offringa, 2014). Starting from
#
# $V(u,v,w) = \int\int \frac{\text{d}l \text{d}m }{\sqrt{1-l^2-m^2}}I(l,m)\exp\left[-i2\pi\left(ul+vm+w\left(\sqrt{1-l^2-m^2}-1\right)\right)\right]	$
#
# The right-hand side can be separated into one part without any $w$-term and the rest which contains the $w$-term. For each given non--zero $w_i$, we have
#
# $V(u,v,w_i) = \int \int \mathrm{d}l \mathrm{d}m \frac{I(l,m)}{\sqrt{1-l^2-m^2}} \exp{[-i2\pi(ul+vm)]}\exp{\Big\{-i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
#
# For each given non-zero $w_i$, this is essentially a two--dimensional Fourier transform. By inverting the transform, we have:
#
# $\frac{I(l,m)}{\sqrt{1-l^2-m^2}} = \int \int \mathrm{d}u \mathrm{d}v V(u,v,w_i)\exp{[i2\pi(ul+vm)]}	\exp{\Big\{i2\pi\Big[w_i\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\} $
#
# If we integrate both sides along the $w$-axis from the minimum $w_{\rm min}$ to the maximum $w_{\rm max}$ on the right-hand side, the result is
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \int_{w_{\rm min}}^{w_{\rm max}} \mathrm{d}w \exp{\Big\{\mathrm{i}2\pi\Big[w\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}$
# $\int \int \mathrm{d}u \mathrm{d}v V(u,v,w)\exp{[i2\pi(ul+vm)]}$
#
# In practice, the values of $w$ are discretised into $N_w$ uniform samples along the $w$-axis,  can be written as:
#
# $\frac{I(l,m)(w_{\rm max} - w_{\rm min})}{\sqrt{1-l^2-m^2}} = \sum_{n = 0}^{N_w-1}\exp{\Big\{i2\pi\Big[w_n\Big(\sqrt{1-l^2-m^2}-1\Big)\Big]}\Big\}\int \int \mathrm{d}u \mathrm{d}v V(u,v,w_n)\exp{[i2\pi(ul+vm)]} $
#
# Following (Offringa, 2014), the separation of two subsequent $w$ values $\delta w$ should satisfy the criterion:
#
# $|\delta w 2\pi(\sqrt{1-l^2-m^2}-1)| \ll 1$
#
# If $\delta w$ is larger than this, more $w$ samples are needed. Hence, $N_w$ is determined by:
#
# $N_w \geq 2\pi(w_{\rm max} - w_{\rm min})\max_{l,m}(1-\sqrt{1-l^2-m^2})$

# %% [markdown]
# ### 2.1 Redetermin the number of w planes
#
# <img src="normalised_coordinate.png">
#
# In the normalised coordinate system plotted above, the field of view is confined in the region of $[-0.5,0.5]$. $x_0$ and $y_0$ represents how much of the image will be cropped after the FFT process （Ye,2019 on optimal gridding and degridding）. Here we have $x_0 = y_0$. The angular size of the map required for the FFT in $l$ is $l_{\rm range}/(2x_0)$, and is $N_x$ pixels. If $u$ is specified in wavelengths, it is multiplied by $l_{\rm range}/(2x_0)$ to convert to pixels, so that we redetermin the number of $w$-planes as:
#
# $N_x \geq (u_{\rm max}-u_{\rm min})l_{\rm range}/x_0$
#
# We now consider the choice of the $w$ or $z$ grid. We set the phase centre $z=0$ at $n=0$ and $z=-x_0$ at $n_{\rm min}$. In our improved W-Stacking, we do not apply FFT in the $z$ direction, so there is no advantage in oversampling the beam considerably. Consequently,
#
# $N_z \geq (w_{\rm max}-w_{\rm min})n_{\rm min}/x_0$
#
# The number of $w$-planes using least-misfit gridding function can therefore be determined as:
#
# $N_{w'} \equiv N_z \geq\frac{\max_{l,m}(1-\sqrt{1-l^2-m^2})(w_{\rm max} - w_{\rm min})}{x_0} + W$
#
# The additional $w$-planes enable visibilities located close to the top or bottom $w$-planes to be gridded to grids on both sides.
#
# The number of $w$-planes, $N_{w}$, determined by the original W-Stacking method is more than 1.5 times greater than the first part of $N_{w'}$. Thus, for given data, the improved W-Stacking method may require fewer $w$--planes than the original W-Stacking method. $x_0 = 0.25, W\geq 7$ is recommended so as to achieve the single precision limit in the image misfit level.

# %% [markdown]
# ### 2. Determine w plane number Nw_2R

# %%
W = 6
M, x0, h = opt_funcs[W].M, opt_funcs[W].x0, opt_funcs[W].h
Nw_2R, w_values, dw = Wplanes(W, X_max, Y_max, w, x0)
# Out:
# We will have 75 w-planes

# %% [markdown]
# ### 3 3D Gridding + Imaging + Correcting
#
# To know more about gridding, you can refer to https://github.com/zoeye859/Imaging-Tutorial
# #### Calculating gridding values for w respectively

# %%
Nfft = 600
im_size = 600
ind = find_nearestw(w_values, w)
C_w = cal_grid_w(w, w_values, ind, dw, W, h, M)
# Out:
# Elapsed time during the w gridding value calculation in seconds: 0.9803849999999998

# %% [markdown]
# #### Gridding on w-axis

# %%
V_wgrid, u_wgrid, v_wgrid, beam_wgrid = grid_w(V, u, v, w, C_w, w_values, W, Nw_2R, ind)
# Out:
# Elapsed time during the w-gridding calculation in seconds: 0.14955600000000002

# %% [markdown]
# #### Imaging

# %%
I_size = int(im_size*2*x0)
I_image = np.zeros((I_size,I_size),dtype = np.complex_)
B_image = np.zeros((I_size,I_size),dtype = np.complex_)

t2_start = process_time() 
for w_ind in range(Nw_2R):
    print ('Gridding the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    V_update = np.asarray(V_wgrid[w_ind])
    u_update = np.asarray(u_wgrid[w_ind])
    v_update = np.asarray(v_wgrid[w_ind])
    beam_update = np.asarray(beam_wgrid[w_ind])
    V_grid, B_grid = grid_uv(V_update, u_update, v_update, beam_update, W, im_size, X_max, X_min, Y_max, Y_min, h, M)
    print ('FFT the ', w_ind, 'th level facet out of ',Nw_2R,' w facets.\n')
    I_image += FFTnPShift(V_grid, w_values[w_ind], X, Y, im_size, x0)
    B_image += FFTnPShift(B_grid, w_values[w_ind], X, Y, im_size, x0)
    B_grid = np.zeros((im_size,im_size),dtype = np.complex_) 
    V_grid = np.zeros((im_size,im_size),dtype = np.complex_)
    
t2_stop = process_time()   
print("Elapsed time during imaging in seconds:", t2_stop-t2_start)
# Out:
# Gridding the  0 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0390950000000001
# Elapsed time during the u/v gridding value calculation in seconds: 0.036185000000000134
# FFT the  0 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  1 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07027800000000006
# Elapsed time during the u/v gridding value calculation in seconds: 0.07686800000000016
# FFT the  1 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  2 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.118201
# Elapsed time during the u/v gridding value calculation in seconds: 0.12596600000000002
# FFT the  2 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  3 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.15630100000000002
# Elapsed time during the u/v gridding value calculation in seconds: 0.15003399999999978
# FFT the  3 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  4 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.17831900000000012
# Elapsed time during the u/v gridding value calculation in seconds: 0.1888419999999993
# FFT the  4 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  5 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.22392400000000023
# Elapsed time during the u/v gridding value calculation in seconds: 0.2236829999999994
# FFT the  5 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  6 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.21626499999999993
# Elapsed time during the u/v gridding value calculation in seconds: 0.22291999999999845
# FFT the  6 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  7 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.21570600000000084
# Elapsed time during the u/v gridding value calculation in seconds: 0.21880400000000044
# FFT the  7 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  8 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.2007469999999998
# Elapsed time during the u/v gridding value calculation in seconds: 0.20811500000000116
# FFT the  8 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  9 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.21485400000000254
# Elapsed time during the u/v gridding value calculation in seconds: 0.21540999999999855
# FFT the  9 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  10 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.21418000000000248
# Elapsed time during the u/v gridding value calculation in seconds: 0.20950200000000052
# FFT the  10 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  11 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1988020000000006
# Elapsed time during the u/v gridding value calculation in seconds: 0.20190400000000253
# FFT the  11 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  12 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1946690000000011
# Elapsed time during the u/v gridding value calculation in seconds: 0.20007299999999972
# FFT the  12 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  13 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.179863000000001
# Elapsed time during the u/v gridding value calculation in seconds: 0.1910330000000009
# FFT the  13 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  14 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1774729999999991
# Elapsed time during the u/v gridding value calculation in seconds: 0.19542300000000168
# FFT the  14 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  15 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.17666200000000032
# Elapsed time during the u/v gridding value calculation in seconds: 0.1806580000000011
# FFT the  15 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  16 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.18054300000000012
# Elapsed time during the u/v gridding value calculation in seconds: 0.1907420000000002
# FFT the  16 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  17 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.16681299999999766
# Elapsed time during the u/v gridding value calculation in seconds: 0.17414500000000288
# FFT the  17 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  18 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.16561300000000045
# Elapsed time during the u/v gridding value calculation in seconds: 0.16533000000000087
# FFT the  18 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  19 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.16378600000000176
# Elapsed time during the u/v gridding value calculation in seconds: 0.16416399999999953
# FFT the  19 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  20 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1557499999999976
# Elapsed time during the u/v gridding value calculation in seconds: 0.15760499999999666
# FFT the  20 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  21 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.14513399999999876
# Elapsed time during the u/v gridding value calculation in seconds: 0.1562720000000013
# FFT the  21 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  22 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1384000000000043
# Elapsed time during the u/v gridding value calculation in seconds: 0.146809999999995
# FFT the  22 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  23 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.1324430000000021
# Elapsed time during the u/v gridding value calculation in seconds: 0.14262599999999992
# FFT the  23 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  24 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.12083599999999706
# Elapsed time during the u/v gridding value calculation in seconds: 0.1267649999999989
# FFT the  24 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  25 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.11392299999999977
# Elapsed time during the u/v gridding value calculation in seconds: 0.11980300000000454
# FFT the  25 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  26 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.11104100000000017
# Elapsed time during the u/v gridding value calculation in seconds: 0.11437200000000303
# FFT the  26 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  27 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09822100000000233
# Elapsed time during the u/v gridding value calculation in seconds: 0.10684900000000397
# FFT the  27 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  28 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09537900000000121
# Elapsed time during the u/v gridding value calculation in seconds: 0.09811799999999948
# FFT the  28 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  29 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.09059400000000295
# Elapsed time during the u/v gridding value calculation in seconds: 0.09732499999999789
# FFT the  29 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  30 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08897699999999986
# Elapsed time during the u/v gridding value calculation in seconds: 0.09315899999999999
# FFT the  30 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  31 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08791700000000446
# Elapsed time during the u/v gridding value calculation in seconds: 0.09004200000000395
# FFT the  31 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  32 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08582299999999776
# Elapsed time during the u/v gridding value calculation in seconds: 0.10189900000000307
# FFT the  32 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  33 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08243399999999923
# Elapsed time during the u/v gridding value calculation in seconds: 0.0870040000000003
# FFT the  33 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  34 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.08117699999999672
# Elapsed time during the u/v gridding value calculation in seconds: 0.07702900000000312
# FFT the  34 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  35 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.07432000000000016
# Elapsed time during the u/v gridding value calculation in seconds: 0.07599799999999846
# FFT the  35 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  36 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.06168500000000421
# Elapsed time during the u/v gridding value calculation in seconds: 0.06998899999999963
# FFT the  36 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  37 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.06466599999999545
# Elapsed time during the u/v gridding value calculation in seconds: 0.06179999999999808
# FFT the  37 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  38 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.051656000000001256
# Elapsed time during the u/v gridding value calculation in seconds: 0.055705999999993594
# FFT the  38 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  39 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.043984999999999275
# Elapsed time during the u/v gridding value calculation in seconds: 0.05157700000000176
# FFT the  39 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  40 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.04021299999999428
# Elapsed time during the u/v gridding value calculation in seconds: 0.04182399999999831
# FFT the  40 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  41 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03516000000000474
# Elapsed time during the u/v gridding value calculation in seconds: 0.03831699999999927
# FFT the  41 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  42 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.03339700000000079
# Elapsed time during the u/v gridding value calculation in seconds: 0.03816100000000233
# FFT the  42 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  43 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.035467999999994504
# Elapsed time during the u/v gridding value calculation in seconds: 0.034382999999998276
# FFT the  43 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  44 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.029711000000006038
# Elapsed time during the u/v gridding value calculation in seconds: 0.032761000000000706
# FFT the  44 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  45 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.029390999999996836
# Elapsed time during the u/v gridding value calculation in seconds: 0.033709000000001765
# FFT the  45 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  46 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.02765399999999829
# Elapsed time during the u/v gridding value calculation in seconds: 0.030498999999998944
# FFT the  46 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  47 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.024663000000003876
# Elapsed time during the u/v gridding value calculation in seconds: 0.02733499999999367
# FFT the  47 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  48 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.02117300000000455
# Elapsed time during the u/v gridding value calculation in seconds: 0.025632000000001653
# FFT the  48 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  49 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.019756000000000995
# Elapsed time during the u/v gridding value calculation in seconds: 0.022623999999993316
# FFT the  49 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  50 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.018032000000005155
# Elapsed time during the u/v gridding value calculation in seconds: 0.025986000000003173
# FFT the  50 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  51 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.016590000000007876
# Elapsed time during the u/v gridding value calculation in seconds: 0.01980500000000518
# FFT the  51 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  52 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.014133000000001061
# Elapsed time during the u/v gridding value calculation in seconds: 0.01637200000000405
# FFT the  52 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  53 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.017277999999990357
# Elapsed time during the u/v gridding value calculation in seconds: 0.014560000000003015
# FFT the  53 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  54 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.009983000000005404
# Elapsed time during the u/v gridding value calculation in seconds: 0.01230300000000284
# FFT the  54 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  55 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00901100000000099
# Elapsed time during the u/v gridding value calculation in seconds: 0.012510000000006016
# FFT the  55 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  56 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.006654000000011706
# Elapsed time during the u/v gridding value calculation in seconds: 0.007953000000000543
# FFT the  56 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  57 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.007274000000009551
# Elapsed time during the u/v gridding value calculation in seconds: 0.00947800000000143
# FFT the  57 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  58 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.003569000000013034
# Elapsed time during the u/v gridding value calculation in seconds: 0.004643000000001507
# FFT the  58 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  59 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0028109999999941238
# Elapsed time during the u/v gridding value calculation in seconds: 0.0039540000000073405
# FFT the  59 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  60 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0021270000000015443
# Elapsed time during the u/v gridding value calculation in seconds: 0.004602000000005546
# FFT the  60 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  61 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0022559999999884894
# Elapsed time during the u/v gridding value calculation in seconds: 0.003910000000004743
# FFT the  61 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  62 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0028480000000001837
# Elapsed time during the u/v gridding value calculation in seconds: 0.005015000000000214
# FFT the  62 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  63 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.003771999999997888
# Elapsed time during the u/v gridding value calculation in seconds: 0.005973999999994817
# FFT the  63 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  64 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.003964000000010515
# Elapsed time during the u/v gridding value calculation in seconds: 0.007291999999992527
# FFT the  64 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  65 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.004343000000005759
# Elapsed time during the u/v gridding value calculation in seconds: 0.005358999999998559
# FFT the  65 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  66 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0037820000000010623
# Elapsed time during the u/v gridding value calculation in seconds: 0.006658000000001607
# FFT the  66 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  67 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.003204999999994129
# Elapsed time during the u/v gridding value calculation in seconds: 0.005693000000007942
# FFT the  67 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  68 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0026630000000125165
# Elapsed time during the u/v gridding value calculation in seconds: 0.0055440000000004375
# FFT the  68 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  69 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0019700000000000273
# Elapsed time during the u/v gridding value calculation in seconds: 0.004970999999997616
# FFT the  69 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  70 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.00221700000000169
# Elapsed time during the u/v gridding value calculation in seconds: 0.002402000000003568
# FFT the  70 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  71 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0012090000000029022
# Elapsed time during the u/v gridding value calculation in seconds: 0.0018460000000004584
# FFT the  71 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  72 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0007779999999968368
# Elapsed time during the u/v gridding value calculation in seconds: 0.0020729999999957727
# FFT the  72 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  73 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.000598999999994021
# Elapsed time during the u/v gridding value calculation in seconds: 0.0008499999999997954
# FFT the  73 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Gridding the  74 th level facet out of  75  w facets.
#
# Elapsed time during the u/v gridding value calculation in seconds: 0.0005599999999930105
# Elapsed time during the u/v gridding value calculation in seconds: 0.0017989999999912243
# FFT the  74 th level facet out of  75  w facets.
#
# FFTing...
# Phaseshifting...
# FFTing...
# Phaseshifting...
# Elapsed time during imaging in seconds: 85.024757

# %% [markdown]
# #### Rescale and have a look

# %%
I_image_now = image_rescale(I_image,im_size, n_uv)
B_image_now = image_rescale(B_image,im_size, n_uv)
plt.figure()
plt.imshow(np.rot90(I_image_now.real,1), origin = 'lower')
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
B_image_now[150,150]
# Out:
# <img src="data:image/png;base64,..." width="1600">
# (1.0000000022353488+0j)

# %% [markdown]
# #### Correcting functions h(x)h(y) on x and y axis

# %% [markdown]
# #### W= 6, x0 = 0.25

# %%
Nfft = 600
# Use these for calculating gridding correction on the FFT grid
M = 32
I_xycorrected = xy_correct(I_image_now, opt_funcs[W], im_size, x0=0.25)
B_xycorrected = xy_correct(B_image_now, opt_funcs[W], im_size, x0=0.25)

# %% [markdown]
# #### Correcting function on z axis

# %%
Cor_gridz = z_correct_cal(X_min, X_max, Y_min, Y_max, dw, h, im_size, W, M, x0)
I_zcorrected = z_correct(I_xycorrected, Cor_gridz, im_size, x0=0.25)
B_zcorrected = z_correct(B_xycorrected, Cor_gridz, im_size, x0=0.25)

# %% [markdown]
# ### 4 DFT and FFT dirty image difference

# %%
I_DFT = np.loadtxt('I_DFT_simul300.csv', delimiter = ',')

# %%
I_dif = I_DFT - I_zcorrected.real
rms = RMS(I_dif, im_size, 0.5, x0=0.25)
plt.figure()
plt.imshow(np.rot90(I_dif,1), origin = 'lower')
plt.colorbar()
plt.xlabel('Image Coordinates X')
plt.ylabel('Image Coordinates Y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
print (rms)
# Out:
# 3.1153852973496086e-07
